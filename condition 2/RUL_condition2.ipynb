# %%
import os
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def read_csv_files(directories):
    """
    Read all of the CSV files in the specified directories.

    Args:
        directories: A comma-separated string of directories that contain the CSV files.

    Returns:
        A list of DataFrames, one for each CSV file.
    """

    dataframes = []
    for directory in directories.split(','):
        csv_files = os.listdir(directory.strip())
        for csv_file in csv_files:
            if csv_file.lower().endswith('.csv'):
                dataframe = pd.read_csv(os.path.join(directory.strip(), csv_file))
                dataframes.append(dataframe)

    return dataframes

def train_rul_model(X_train, y_train):
    """
    Train a Random Forest Regressor model on the given data.

    Args:
        X_train: The feature matrix for training.
        y_train: The target variable vector for training.

    Returns:
        The trained Random Forest Regressor model.
    """

    # Create and train the Random Forest Regressor
    rul_model = RandomForestRegressor(random_state=42)
    rul_model.fit(X_train, y_train)

    return rul_model

def main():
    # Get the list of CSV files in the directory
    directory = "/content/drive/MyDrive/fsm/Learning_set/Bearing2_1,/content/drive/MyDrive/fsm/Learning_set/Bearing2_2"
    csv_files = read_csv_files(directory)

    # Loop over the CSV files and train a model on each one
    for data in csv_files:
        # Print column names to find the correct name of the target variable (RUL) column
        print(data.columns)

        # Assume the target variable is in the last column (index -1)
        target_column_index = -1
        X = data.drop(data.columns[target_column_index], axis=1)
        y = data[data.columns[target_column_index]]

        # Initialize the imputer with the desired strategy (e.g., mean, median, most frequent)
        imputer = SimpleImputer(strategy='mean')

        # Fit the imputer on the data and transform
        X_imputed = imputer.fit_transform(X)

        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

        # Train the RUL prediction model and get the trained model
        rul_model = train_rul_model(X_train, y_train)

        # Evaluate the model's performance on the test set (e.g., using R-squared score)
        score = rul_model.score(X_test, y_test)
        print("R-squared score:", score)

if __name__ == "__main__":
    main()
# Out:
# Index(['8', '26', '5', '8.8441e+05', '-0.399', '0.52'], dtype='object')
# R-squared score: -0.00034272634576604233
# Index(['8', '55', '55.1', '8.8441e+05', '0.095', '0.651'], dtype='object')
# R-squared score: 0.5627001636724378
# Index(['8', '30', '15', '8.8441e+05', '-0.363', '0.048'], dtype='object')
# R-squared score: -0.029558388339580688
# Index(['9', '34', '25', '8.8441e+05', '-0.122', '0.081'], dtype='object')
# R-squared score: 0.6180890717088843
# Index(['9', '51', '55', '8.8441e+05', '-1.067', '1.492'], dtype='object')
# R-squared score: 0.7127009622644982
# Index(['10', '9', '45', '8.8441e+05', '0.584', '-1.796'], dtype='object')
# R-squared score: 0.6579731719210713
# Index(['8', '27', '15', '8.8441e+05', '0.055', '-0.189'], dtype='object')
# R-squared score: -0.01913768070048638
# Index(['9', '45', '55', '8.8441e+05', '-0.425', '0.772'], dtype='object')
# R-squared score: 0.6086191629740141
# Index(['9', '41', '35', '8.8441e+05', '-1.221', '1.014'], dtype='object')
# R-squared score: 0.6238885550731024
# Index(['9', '52', '5', '8.8441e+05', '0.659', '-0.618'], dtype='object')
# R-squared score: 0.18310209645543174
# Index(['10', '6', '35', '8.8441e+05', '-0.466', '0.204'], dtype='object')
# R-squared score: 0.6441624794753963
# Index(['10', '14', '55', '8.8441e+05', '-0.259', '0.127'], dtype='object')
# R-squared score: 0.6719905732954731
# Index(['8', '53', '15', '8.8441e+05', '-0.155', '0.071'], dtype='object')
# R-squared score: 0.6347844143877414
# Index(['10', '40', '15', '8.8441e+05', '-0.536', '1.138'], dtype='object')
# R-squared score: 0.28596713734366674
# Index(['9', '5', '35', '8.8441e+05', '1.363', '-0.736'], dtype='object')
# R-squared score: 0.7171989334866509
# Index(['9', '36', '55', '8.8441e+05', '0.229', '-0.368'], dtype='object')
# R-squared score: 0.6555228255279277
# Index(['9', '8', '25', '8.8441e+05', '0.895', '-0.621'], dtype='object')
# R-squared score: 0.6683204893550982
# Index(['9', '35', '55', '8.8441e+05', '-1.447', '1.976'], dtype='object')
# R-squared score: 0.5889795893315779
# Index(['10', '32', '15', '8.8441e+05', '-0.453', '0.599'], dtype='object')
# R-squared score: 0.6319368339960685
# Index(['9', '13', '55', '8.8441e+05', '0.825', '-0.389'], dtype='object')
# R-squared score: 0.6644161432542844
# Index(['9', '31', '55', '8.8441e+05', '0.319', '-0.745'], dtype='object')
# R-squared score: 0.6154595114802721
# Index(['8', '40', '55', '8.8441e+05', '0.052', '0.285'], dtype='object')
# R-squared score: 0.37942679844417015
# Index(['10', '0', '45', '8.8441e+05', '0.401', '-0.773'], dtype='object')
# R-squared score: 0.2168934856663861
# Index(['9', '20', '15', '8.8441e+05', '0.948', '-0.333'], dtype='object')
# R-squared score: 0.6870473667426024
# Index(['9', '27', '35', '8.8441e+05', '-0.286', '0.696'], dtype='object')
# R-squared score: 0.5990199431306868
# Index(['8', '31', '55', '8.8441e+05', '0.351', '-0.213'], dtype='object')
# R-squared score: -0.12239713508750527
# Index(['9', '41', '45', '8.8441e+05', '0.324', '0.338'], dtype='object')
# R-squared score: 0.5590127087926684
# Index(['8', '53', '55', '8.8441e+05', '0.067', '0.135'], dtype='object')
# R-squared score: 0.5874906394980337
# Index(['10', '8', '25', '8.8441e+05', '-0.203', '0.389'], dtype='object')
# R-squared score: 0.6706107280185564
# Index(['10', '23', '35', '8.8441e+05', '0.349', '-0.825'], dtype='object')
# R-squared score: 0.661821213123329
# Index(['10', '26', '55', '8.8441e+05', '-0.879', '0.862'], dtype='object')
# R-squared score: 0.6107012584420526
# Index(['10', '11', '45', '8.8441e+05', '0.719', '-1.503'], dtype='object')
# R-squared score: 0.608312406152847
# Index(['10', '35', '55', '8.8441e+05', '0.076', '-0.18'], dtype='object')
# R-squared score: 0.3237044578314934
# Index(['10', '38', '35', '8.8441e+05', '-0.802', '0.012'], dtype='object')
# R-squared score: -0.0963283898262779
# Index(['9', '21', '25', '8.8441e+05', '-0.816', '0.688'], dtype='object')
# R-squared score: 0.6823831021307718
# Index(['8', '58', '15', '8.8441e+05', '0.721', '-0.779'], dtype='object')
# R-squared score: 0.5578872850561427
# Index(['8', '14', '25', '8.8441e+05', '-0.142', '-0.755'], dtype='object')
# R-squared score: -0.1271666992570819
# Index(['8', '29', '45', '8.8441e+05', '-0.154', '0.091'], dtype='object')
# R-squared score: -0.02751305143445859
# Index(['8', '34', '55', '8.8441e+05', '-0.017', '0.202'], dtype='object')
# R-squared score: 0.25289407060344804
# Index(['8', '40', '5', '8.8441e+05', '0.052', '1.108'], dtype='object')
# R-squared score: 0.4918423186196563
# Index(['9', '5', '45', '8.8441e+05', '-1.059', '0.97'], dtype='object')
# R-squared score: 0.7166672396087248
# Index(['10', '8', '55', '8.8441e+05', '0.571', '-0.511'], dtype='object')
# R-squared score: 0.630037818294495
# Index(['10', '42', '15', '8.8441e+05', '1.037', '-3.578'], dtype='object')
# R-squared score: 0.39208149113203483
# Index(['9', '52', '15', '8.8441e+05', '-2.023', '3.029'], dtype='object')
# R-squared score: 0.6988900616550004
# Index(['8', '54', '45', '8.8441e+05', '-0.559', '0.309'], dtype='object')
# R-squared score: 0.67854731404418
# Index(['10', '10.1', '5', '8.8441e+05', '0.876', '-1.022'], dtype='object')
# R-squared score: 0.6301826921457181
# Index(['8', '55', '35', '8.8441e+05', '0.495', '0.304'], dtype='object')
# R-squared score: 0.6257542594819112
# Index(['8', '52', '45', '8.8441e+05', '0.55', '-1.146'], dtype='object')
# R-squared score: 0.6406215067956609
# Index(['8', '22', '25', '8.8441e+05', '-0.493', '-0.121'], dtype='object')
# R-squared score: -0.1313291018266891
# Index(['9', '27', '15', '8.8441e+05', '-0.126', '-0.135'], dtype='object')
# R-squared score: 0.5721732781967129
# Index(['10', '32', '35', '8.8441e+05', '-0.216', '0.151'], dtype='object')
# R-squared score: 0.6307427726397229
# Index(['10', '41', '55', '8.8441e+05', '0.257', '0.119'], dtype='object')
# R-squared score: 0.29765658493526004
# Index(['8', '15', '55', '8.8441e+05', '-1.544', '-0.187'], dtype='object')
# R-squared score: -0.15168503178097792
# Index(['8', '46', '25', '8.8441e+05', '-0.723', '1.893'], dtype='object')
# R-squared score: 0.6223167316598477
# Index(['8', '46', '55', '8.8441e+05', '0.152', '0.402'], dtype='object')
# R-squared score: 0.5565142363490686
# Index(['9', '1', '25', '8.8441e+05', '0.605', '-0.194'], dtype='object')
# R-squared score: 0.7053260072026133
# Index(['9', '5', '25', '8.8441e+05', '-0.148', '0.643'], dtype='object')
# R-squared score: 0.6528991597871565
# Index(['9', '12', '45', '8.8441e+05', '-0.428', '0.898'], dtype='object')
# R-squared score: 0.6680906887894358
# Index(['9', '46', '55', '8.8441e+05', '0.356', '-0.133'], dtype='object')
# R-squared score: 0.5875533955751476
# Index(['8', '24', '45', '8.8441e+05', '-0.026', '0.424'], dtype='object')
# R-squared score: -0.0033134379046420026
# Index(['10', '26', '5', '8.8441e+05', '-0.121', '0.004'], dtype='object')
# R-squared score: 0.40676178989644496
# Index(['10', '38', '45', '8.8441e+05', '0.807', '-1.212'], dtype='object')
# R-squared score: 0.558151385016681
# Index(['9', '54', '5', '8.8441e+05', '0.784', '-0.648'], dtype='object')
# R-squared score: 0.460628479609666
# Index(['9', '5', '55', '8.8441e+05', '-0.767', '0.847'], dtype='object')
# R-squared score: 0.6738073655628899
# Index(['9', '42', '35', '8.8441e+05', '-0.011', '-0.022'], dtype='object')
# R-squared score: 0.6398980391603242
# Index(['8', '17', '55', '8.8441e+05', '-0.923', '0.387'], dtype='object')
# R-squared score: -0.2871002327286827
# Index(['9', '57', '15', '8.8441e+05', '0.367', '-0.659'], dtype='object')
# R-squared score: 0.7018056312010033
# Index(['10', '19', '5', '8.8441e+05', '-1.721', '1.923'], dtype='object')
# R-squared score: 0.6606537149788485
# Index(['10', '40', '45', '8.8441e+05', '0.633', '-0.783'], dtype='object')
# R-squared score: -0.23499626986710864
# Index(['9', '52', '55', '8.8441e+05', '0.407', '0.001'], dtype='object')
# R-squared score: 0.6317727521341363
# Index(['10', '7', '25', '8.8441e+05', '-0.03', '-0.35'], dtype='object')
# R-squared score: 0.6813558324901532
# Index(['8', '54', '5', '8.8441e+05', '-0.472', '0.731'], dtype='object')
# R-squared score: 0.4961893203501323
# Index(['9', '17', '35', '8.8441e+05', '0.206', '-0.006'], dtype='object')
# R-squared score: 0.7347267441486238
# Index(['8', '55', '45', '8.8441e+05', '-0.634', '0.458'], dtype='object')
# R-squared score: 0.6076205269560022
# Index(['8', '21', '15', '8.8441e+05', '-0.223', '0.52'], dtype='object')
# R-squared score: -0.14219990045471342
# Index(['9', '32', '55', '8.8441e+05', '0.668', '-1.085'], dtype='object')
# R-squared score: 0.6163926775503061
# Index(['9', '18', '45', '8.8441e+05', '0.541', '-0.784'], dtype='object')
# R-squared score: 0.691917701070317
# Index(['8', '57', '15', '8.8441e+05', '1.127', '-2.134'], dtype='object')
# R-squared score: 0.5930295515487967
# Index(['9', '6', '35', '8.8441e+05', '1.039', '-1.447'], dtype='object')
# R-squared score: 0.6268964257124977
# Index(['10', '22', '35', '8.8441e+05', '0.766', '-1.039'], dtype='object')
# R-squared score: 0.4652184256555896
# Index(['9', '0', '25', '8.8441e+05', '-0.168', '-0.461'], dtype='object')
# R-squared score: 0.6923761393121888
# Index(['10', '31', '55', '8.8441e+05', '0.188', '-0.94'], dtype='object')
# R-squared score: -0.20575164676717028
# Index(['8', '53', '45', '8.8441e+05', '-0.976', '1.457'], dtype='object')
# R-squared score: 0.6234955167124563
# Index(['9', '48', '15', '8.8441e+05', '0.342', '-1.058'], dtype='object')
# R-squared score: 0.6679126504672697
# Index(['8', '39', '55', '8.8441e+05', '0.107', '-0.818'], dtype='object')
# R-squared score: 0.5330443058417711
# Index(['8', '46', '5', '8.8441e+05', '-0.328', '0.588'], dtype='object')
# R-squared score: 0.6238610652630818
# Index(['9', '3', '55', '8.8441e+05', '-0.789', '0.416'], dtype='object')
# R-squared score: 0.6644299928092403
# Index(['10', '23', '55', '8.8441e+05', '-0.772', '0.926'], dtype='object')
# R-squared score: 0.5322495077751374
# Index(['10', '14', '5', '8.8441e+05', '-0.21', '0.171'], dtype='object')
# R-squared score: 0.6084145983173871
# Index(['10', '24', '35', '8.8441e+05', '-0.43', '0.945'], dtype='object')
# R-squared score: 0.6105391087860887
# Index(['8', '46', '35', '8.8441e+05', '0.642', '-0.345'], dtype='object')
# R-squared score: 0.5578467965859477
# Index(['9', '31', '5', '8.8441e+05', '-0.408', '0.428'], dtype='object')
# R-squared score: 0.6712641090271299
# Index(['10', '26', '15', '8.8441e+05', '-0.16', '-0.242'], dtype='object')
# R-squared score: 0.5968232145308117
# Index(['10', '21', '55', '8.8441e+05', '0.082', '-0.201'], dtype='object')
# R-squared score: 0.5856503414390553
# Index(['10', '38', '25', '8.8441e+05', '0.537', '-0.764'], dtype='object')
# R-squared score: 0.5862610678527325
# Index(['10', '27', '15', '8.8441e+05', '0.128', '-0.331'], dtype='object')
# R-squared score: 0.6123021889085052
# Index(['8', '29', '15', '8.8441e+05', '-0.279', '-0.142'], dtype='object')
# R-squared score: 0.05382896872282239
# Index(['10', '25', '55', '8.8441e+05', '-0.072', '0.308'], dtype='object')
# R-squared score: 0.5717097778408948
# Index(['10', '8', '5', '8.8441e+05', '-0.138', '0.397'], dtype='object')
# R-squared score: 0.6597779340209252
# Index(['8', '44', '55', '8.8441e+05', '0.805', '-0.683'], dtype='object')
# R-squared score: 0.5584946302416962
# Index(['10', '38', '5', '8.8441e+05', '-0.309', '0.177'], dtype='object')
# R-squared score: 0.5380505684399699
# Index(['9', '32', '15', '8.8441e+05', '-0.916', '0.732'], dtype='object')
# R-squared score: 0.7012313332516519
# Index(['8', '41', '25', '8.8441e+05', '-0.504', '0.305'], dtype='object')
# R-squared score: 0.47643517402762825
# Index(['10', '42', '45', '8.8441e+05', '-0.444', '0.186'], dtype='object')
# R-squared score: 0.3129718888998324
# Index(['10', '7', '5', '8.8441e+05', '0.494', '0.185'], dtype='object')
# R-squared score: 0.676324269570352
# Index(['8', '24', '55', '8.8441e+05', '-0.062', '-0.107'], dtype='object')
# R-squared score: -0.07325632405359195
# Index(['9', '58', '55', '8.8441e+05', '0.591', '-1.198'], dtype='object')
# R-squared score: 0.6235212972970136
# Index(['10', '23', '25', '8.8441e+05', '-0.295', '0.031'], dtype='object')
# R-squared score: 0.6313963064838952
# Index(['9', '53', '35', '8.8441e+05', '-0.63', '0.502'], dtype='object')
# R-squared score: 0.4716773339715983
# Index(['9', '1', '45', '8.8441e+05', '-0.386', '0.173'], dtype='object')
# R-squared score: 0.5411362549365695
# Index(['8', '30', '25', '8.8441e+05', '0.054', '-0.102'], dtype='object')
# R-squared score: 0.029046590434020025
# Index(['10', '3', '45', '8.8441e+05', '-0.178', '0.166'], dtype='object')
# R-squared score: 0.6902433630152092
# Index(['8', '23', '5', '8.8441e+05', '-0.443', '-0.295'], dtype='object')
# R-squared score: -0.12726046332328877
# Index(['8', '26', '45', '8.8441e+05', '0.345', '0.139'], dtype='object')
# R-squared score: 0.01905763723831766
# Index(['9', '57', '5', '8.8441e+05', '-0.21', '0.056'], dtype='object')
# R-squared score: 0.593015254839715
# Index(['10', '9', '55', '8.8441e+05', '-0.055', '0.128'], dtype='object')
# R-squared score: 0.6113364744066991
# Index(['8', '47', '45', '8.8441e+05', '-0.521', '1.131'], dtype='object')
# R-squared score: 0.5468936910636928
# Index(['10', '22', '5', '8.8441e+05', '-0.155', '0.455'], dtype='object')
# R-squared score: 0.661790150573925
# Index(['9', '40', '25', '8.8441e+05', '-0.492', '0.788'], dtype='object')
# R-squared score: 0.674906330960743
# Index(['10', '38', '55', '8.8441e+05', '-1.616', '1.377'], dtype='object')
# R-squared score: 0.26210667634848617
# Index(['9', '21', '5', '8.8441e+05', '0.36', '0.052'], dtype='object')
# R-squared score: 0.6537197006826968
# Index(['9', '19', '45', '8.8441e+05', '0.516', '-0.743'], dtype='object')
# R-squared score: 0.6712060847983403
# Index(['9', '25', '55', '8.8441e+05', '0.679', '-0.592'], dtype='object')
# R-squared score: 0.6290851194268782
# Index(['8', '23', '15', '8.8441e+05', '-0.002', '-0.033'], dtype='object')
# R-squared score: -0.18172423937352522
# Index(['9', '0', '35', '8.8441e+05', '0.423', '-0.587'], dtype='object')
# R-squared score: 0.6659178103207856
# Index(['9', '43', '35', '8.8441e+05', '-0.095', '-0.169'], dtype='object')
# R-squared score: 0.6263288745433299
# Index(['10', '8', '15', '8.8441e+05', '1.639', '-0.591'], dtype='object')
# R-squared score: 0.6720004651155198
# Index(['9', '17', '5', '8.8441e+05', '-0.282', '0.21'], dtype='object')
# R-squared score: 0.6524413395454308
# Index(['9', '41', '25', '8.8441e+05', '-0.716', '0.299'], dtype='object')
# R-squared score: 0.6466654843916915
# Index(['9', '28', '25', '8.8441e+05', '-0.071', '-0.214'], dtype='object')
# R-squared score: 0.5801660374870689
# Index(['8', '25', '55', '8.8441e+05', '0.194', '-0.278'], dtype='object')
# R-squared score: -0.028066258264327626
# Index(['8', '19', '15', '8.8441e+05', '-0.381', '0.227'], dtype='object')
# R-squared score: -0.14895050532096876
# Index(['9', '6', '5', '8.8441e+05', '0.423', '-0.941'], dtype='object')
# R-squared score: 0.6801366361861885
# Index(['9', '59', '35', '8.8441e+05', '0.864', '-1.522'], dtype='object')
# R-squared score: 0.6849408275144093
# Index(['10', '31', '25', '8.8441e+05', '-0.37', '0.815'], dtype='object')
# R-squared score: 0.5956572585444596
# Index(['9', '29', '5', '8.8441e+05', '-0.1', '0.329'], dtype='object')
# R-squared score: 0.575743755684893
# Index(['8', '27', '45', '8.8441e+05', '0.205', '-0.224'], dtype='object')
# R-squared score: 0.033309047945146886
# Index(['9', '35', '45', '8.8441e+05', '-0.344', '0.839'], dtype='object')
# R-squared score: 0.6319810250166871
# Index(['9', '37', '15', '8.8441e+05', '-0.301', '0.15'], dtype='object')
# R-squared score: 0.5904807477822505
# Index(['9', '38', '25', '8.8441e+05', '0.124', '-0.362'], dtype='object')
# R-squared score: 0.5493091033426529
# Index(['9', '11', '5', '8.8441e+05', '-1.563', '2.491'], dtype='object')
# R-squared score: 0.6841191864514484
# Index(['9', '56', '55', '8.8441e+05', '0.085', '-0.308'], dtype='object')
# R-squared score: 0.6040428434792215
# Index(['8', '22', '35', '8.8441e+05', '0.408', '-0.2'], dtype='object')
# R-squared score: -0.16964271659697627
# Index(['10', '37', '45', '8.8441e+05', '0.042', '0.508'], dtype='object')
# R-squared score: 0.6164391141002928
# Index(['10', '15', '25', '8.8441e+05', '0.178', '-0.065'], dtype='object')
# R-squared score: 0.664738127249129
# Index(['8', '31', '15', '8.8441e+05', '0.175', '-0.085'], dtype='object')
# R-squared score: 0.04545851096014575
# Index(['9', '50', '5', '8.8441e+05', '-0.809', '0.663'], dtype='object')
# R-squared score: 0.567918942323773
# Index(['9', '8', '45', '8.8441e+05', '1.373', '-1.317'], dtype='object')
# R-squared score: 0.6447268069329773
# Index(['9', '44', '5', '8.8441e+05', '0.497', '-0.624'], dtype='object')
# R-squared score: 0.6183986576193927
# Index(['9', '15', '55', '8.8441e+05', '-0.364', '-0.119'], dtype='object')
# R-squared score: 0.7137866868458622
# Index(['10', '7', '45', '8.8441e+05', '0.395', '-1.086'], dtype='object')
# R-squared score: 0.6480850887970498
# Index(['8', '26', '35', '8.8441e+05', '-0.125', '-0.31'], dtype='object')
# R-squared score: -0.04840658579979484
# Index(['8', '52', '5', '8.8441e+05', '-0.84', '-0.3'], dtype='object')
# R-squared score: 0.61984197189981
# Index(['10', '37', '5', '8.8441e+05', '-0.777', '0.743'], dtype='object')
# R-squared score: 0.6219292052599641
# Index(['8', '37', '5', '8.8441e+05', '0.169', '0'], dtype='object')
# R-squared score: 0.2985011936231715
# Index(['9', '38', '5', '8.8441e+05', '0.23', '-0.487'], dtype='object')
# R-squared score: 0.6187852972867522
# Index(['10', '3', '35', '8.8441e+05', '-0.027', '0.968'], dtype='object')
# R-squared score: 0.6748872946388362
# Index(['8', '55', '25', '8.8441e+05', '-0.72', '1.607'], dtype='object')
# R-squared score: 0.575621257033883
# Index(['10', '24', '55', '8.8441e+05', '1.235', '-1.563'], dtype='object')
# R-squared score: 0.6472360859731479
# Index(['10', '22', '45', '8.8441e+05', '1.14', '-1.834'], dtype='object')
# R-squared score: 0.6600175331088792
# Index(['10', '44', '15', '8.8441e+05', '-0.972', '-0.436'], dtype='object')
# R-squared score: 0.14735049165394398
# Index(['10', '37', '35', '8.8441e+05', '-0.316', '1.651'], dtype='object')
# R-squared score: -0.020334766640502266
# Index(['8', '15', '25', '8.8441e+05', '0.159', '0.093'], dtype='object')
# R-squared score: -0.27823191270800685
# Index(['9', '56', '25', '8.8441e+05', '-0.996', '1.751'], dtype='object')
# R-squared score: 0.6857250144245381
# Index(['10', '33', '45', '8.8441e+05', '0.364', '0.079'], dtype='object')
# R-squared score: -0.14220780925883947
# Index(['10', '43', '55', '8.8441e+05', '0.373', '0.194'], dtype='object')
# R-squared score: 0.23159313246107316
# Index(['9', '38', '55', '8.8441e+05', '-0.682', '1.136'], dtype='object')
# R-squared score: 0.5254690771499397
# Index(['10', '36', '35', '8.8441e+05', '0.312', '-0.086'], dtype='object')
# R-squared score: 0.6411359109576562
# Index(['9', '49', '25', '8.8441e+05', '0.604', '-0.904'], dtype='object')
# R-squared score: 0.6700485660107751
# Index(['9', '3', '15', '8.8441e+05', '-0.525', '1.099'], dtype='object')
# R-squared score: 0.6888069575031346
# Index(['8', '49', '25', '8.8441e+05', '0.578', '-0.209'], dtype='object')
# R-squared score: 0.5025145326342764
# Index(['9', '58', '25', '8.8441e+05', '0.819', '-1.316'], dtype='object')
# R-squared score: 0.6518744853987644
# Index(['10', '17', '55', '8.8441e+05', '0.198', '-0.613'], dtype='object')
# R-squared score: 0.5902092306983664
# Index(['8', '25', '15', '8.8441e+05', '0.204', '-0.172'], dtype='object')
# R-squared score: -0.03275545807339242
# Index(['8', '28', '15', '8.8441e+05', '-0.28', '-0.052'], dtype='object')
# R-squared score: 0.056633864954184654
# Index(['9', '44', '25', '8.8441e+05', '-0.198', '0.332'], dtype='object')
# R-squared score: 0.6793246058963492
# Index(['8', '57', '5', '8.8441e+05', '-1.385', '2.322'], dtype='object')
# R-squared score: 0.6458234722197935
# Index(['10', '36', '15', '8.8441e+05', '0.901', '3.786'], dtype='object')
# R-squared score: 0.13418081964984496
# Index(['8', '33', '45', '8.8441e+05', '0.266', '0.049'], dtype='object')
# R-squared score: 0.08953563731386782
# Index(['9', '37', '35', '8.8441e+05', '0.079', '-0.402'], dtype='object')
# R-squared score: 0.47683421486537647
# Index(['10', '3', '55', '8.8441e+05', '-0.321', '0.061'], dtype='object')
# R-squared score: 0.65869780144544
# Index(['8', '58', '55', '8.8441e+05', '-0.273', '-0.3'], dtype='object')
# R-squared score: 0.543551580331963
# Index(['9', '10', '55', '8.8441e+05', '-1.123', '1.637'], dtype='object')
# R-squared score: 0.7242996828528172
# Index(['8', '49', '15', '8.8441e+05', '1.505', '-2.512'], dtype='object')
# R-squared score: 0.608740314030184
# Index(['10', '19', '15', '8.8441e+05', '0.216', '-0.891'], dtype='object')
# R-squared score: 0.6318139801312024
# Index(['10', '19', '25', '8.8441e+05', '-0.313', '1.456'], dtype='object')
# R-squared score: 0.6587315157567559
# Index(['9', '17', '25', '8.8441e+05', '0.129', '-0.519'], dtype='object')
# R-squared score: 0.6289155658413286
# Index(['9', '44', '15', '8.8441e+05', '-0.424', '0.205'], dtype='object')
# R-squared score: 0.6944819306070162
# Index(['8', '43', '35', '8.8441e+05', '0.415', '-0.003'], dtype='object')
# R-squared score: 0.5815188861416691
# Index(['9', '22', '5', '8.8441e+05', '0.351', '0.201'], dtype='object')
# R-squared score: 0.640734957214339
# Index(['9', '28', '45', '8.8441e+05', '-0.054', '0.016'], dtype='object')
# R-squared score: 0.5282843544344569
# Index(['8', '42', '55', '8.8441e+05', '0.349', '-0.355'], dtype='object')
# R-squared score: 0.5262721567459757
# Index(['9', '3', '35', '8.8441e+05', '-0.637', '0.94'], dtype='object')
# R-squared score: 0.7148819140516584
# Index(['8', '50', '5', '8.8441e+05', '0.447', '0.021'], dtype='object')
# R-squared score: 0.45036948850297065
# Index(['8', '58', '5', '8.8441e+05', '-0.174', '-0.69'], dtype='object')
# R-squared score: 0.5793638498037881
# Index(['8', '16', '5', '8.8441e+05', '0.213', '-0.437'], dtype='object')
# R-squared score: -0.12773309760261187
# Index(['9', '31', '25', '8.8441e+05', '0.623', '-1.078'], dtype='object')
# R-squared score: 0.6218451891122907
# Index(['8', '59', '55', '8.8441e+05', '1.032', '-0.488'], dtype='object')
# R-squared score: 0.6610576060322135
# Index(['9', '54', '15', '8.8441e+05', '-0.126', '0.5'], dtype='object')
# R-squared score: 0.6004842293445818
# Index(['9', '29', '25', '8.8441e+05', '-0.099', '-0.039'], dtype='object')
# R-squared score: 0.6397890500189805
# Index(['9', '55', '25', '8.8441e+05', '-0.184', '0.147'], dtype='object')
# R-squared score: 0.5767544975783515
# Index(['8', '14', '55', '8.8441e+05', '-0.803', '0.294'], dtype='object')
# R-squared score: -0.13020265937900777
# Index(['10', '20', '45', '8.8441e+05', '-0.135', '0.122'], dtype='object')
# R-squared score: 0.6370588301518367
# Index(['9', '27', '45', '8.8441e+05', '0.366', '-0.28'], dtype='object')
# R-squared score: 0.6157734263397008
# Index(['8', '47', '15', '8.8441e+05', '1.057', '-0.852'], dtype='object')
# R-squared score: 0.6220388846347966
# Index(['8', '34', '25', '8.8441e+05', '-0.039', '0.185'], dtype='object')
# R-squared score: 0.07202962371595634
# Index(['10', '3', '25', '8.8441e+05', '0.338', '-0.192'], dtype='object')
# R-squared score: 0.6165486442542043
# Index(['10', '3', '5', '8.8441e+05', '0.845', '-1.865'], dtype='object')
# R-squared score: 0.6704146296841995
# Index(['10', '10.1', '35', '8.8441e+05', '0.528', '-0.18'], dtype='object')
# R-squared score: 0.6506918391473543
# Index(['9', '5', '5.1', '8.8441e+05', '-1.038', '1.139'], dtype='object')
# R-squared score: 0.6499389258283879
# Index(['10', '29', '5', '8.8441e+05', '-0.496', '0.422'], dtype='object')
# R-squared score: 0.5513740785685198
# Index(['10', '24', '5', '8.8441e+05', '0.226', '-0.904'], dtype='object')
# R-squared score: 0.5862637963751136
# Index(['9', '24', '15', '8.8441e+05', '-0.466', '0.425'], dtype='object')
# R-squared score: 0.6665061645212185
# Index(['9', '57', '25', '8.8441e+05', '-0.315', '0.551'], dtype='object')
# R-squared score: 0.6280260805143213
# Index(['9', '36', '25', '8.8441e+05', '0.585', '-0.77'], dtype='object')
# R-squared score: 0.5899755759523785
# Index(['8', '45', '5', '8.8441e+05', '0.142', '-0.489'], dtype='object')
# R-squared score: 0.6470405185706734
# Index(['10', '5', '45', '8.8441e+05', '-0.766', '0.646'], dtype='object')
# R-squared score: 0.5543127885375014
# Index(['10', '15', '55', '8.8441e+05', '-0.921', '0.676'], dtype='object')
# R-squared score: 0.6530519056019246
# Index(['9', '46', '25', '8.8441e+05', '0.833', '-0.338'], dtype='object')
# R-squared score: 0.6521854986401923
# Index(['10', '45', '15', '8.8441e+05', '-1.874', '2.917'], dtype='object')
# R-squared score: 0.015374887152942884
# Index(['9', '38', '15', '8.8441e+05', '0.101', '-0.199'], dtype='object')
# R-squared score: 0.6108879854651581
# Index(['9', '7', '55', '8.8441e+05', '-0.35', '0.063'], dtype='object')
# R-squared score: 0.6830929861062378
# Index(['9', '39', '55', '8.8441e+05', '0.1', '0.419'], dtype='object')
# R-squared score: 0.5299790762548864
# Index(['9', '47', '35', '8.8441e+05', '0.307', '-0.268'], dtype='object')
# R-squared score: 0.6499789811502862
# Index(['10', '17', '45', '8.8441e+05', '-0.295', '0.913'], dtype='object')
# R-squared score: 0.596082151206875
# Index(['9', '46', '45', '8.8441e+05', '1.088', '-0.95'], dtype='object')
# R-squared score: 0.595319476007039
# Index(['9', '16', '45', '8.8441e+05', '0.331', '0.224'], dtype='object')
# R-squared score: 0.7222778143799611
# Index(['9', '55', '45', '8.8441e+05', '0.469', '-1.503'], dtype='object')
# R-squared score: 0.0225434189178223
# Index(['9', '14', '35', '8.8441e+05', '-1.249', '1.303'], dtype='object')
# R-squared score: 0.6948663580511183
# Index(['8', '50', '15', '8.8441e+05', '0.304', '-0.192'], dtype='object')
# R-squared score: 0.6178552766368686
# Index(['10', '43', '45', '8.8441e+05', '0.201', '1.331'], dtype='object')
# R-squared score: 0.32065062212985085
# Index(['8', '51', '25', '8.8441e+05', '0.815', '-1.163'], dtype='object')
# R-squared score: 0.5694286507115631
# Index(['9', '11', '55', '8.8441e+05', '0.115', '0.064'], dtype='object')
# R-squared score: 0.6434094057315123
# Index(['8', '28', '55', '8.8441e+05', '0.272', '0.32'], dtype='object')
# R-squared score: 0.07989795790126075
# Index(['8', '32', '15', '8.8441e+05', '-0.224', '-0.164'], dtype='object')
# R-squared score: 0.01515671303108268
# Index(['10', '44', '35', '8.8441e+05', '1.76', '-4.006'], dtype='object')
# R-squared score: 0.25550175093752026
# Index(['10', '9', '25', '8.8441e+05', '-0.007', '-0.873'], dtype='object')
# R-squared score: 0.6335303796527809
# Index(['8', '34', '45', '8.8441e+05', '-0.109', '0.146'], dtype='object')
# R-squared score: 0.19725956934271538
# Index(['10', '45', '55', '8.8441e+05', '0.733', '-0.579'], dtype='object')
# R-squared score: 0.18598420569127583
# Index(['8', '19', '55', '8.8441e+05', '0.361', '0.035'], dtype='object')
# R-squared score: -0.12889850564463057
# Index(['9', '44', '55', '8.8441e+05', '0.33', '-0.526'], dtype='object')
# R-squared score: 0.6403035302886574
# Index(['10', '28', '25', '8.8441e+05', '-0.807', '0.647'], dtype='object')
# R-squared score: 0.49244438708740945
# Index(['10', '13', '15', '8.8441e+05', '-1.152', '1.223'], dtype='object')
# R-squared score: 0.6353397817901993
# Index(['9', '48', '45', '8.8441e+05', '-0.939', '1.077'], dtype='object')
# R-squared score: 0.5983153117117428
# Index(['8', '58', '45', '8.8441e+05', '-0.73', '0.505'], dtype='object')
# R-squared score: 0.48706267189276065
# Index(['10', '39', '45', '8.8441e+05', '0.153', '-0.022'], dtype='object')
# R-squared score: 0.49232809405966993
# Index(['9', '52', '45', '8.8441e+05', '-0.844', '0.672'], dtype='object')
# R-squared score: 0.6254474409061381
# Index(['8', '22', '5', '8.8441e+05', '0.302', '-0.174'], dtype='object')
# R-squared score: -0.2296891650445878
# Index(['10', '31', '5', '8.8441e+05', '-0.076', '0.161'], dtype='object')
# R-squared score: 0.5965550980444498
# Index(['10', '37', '25', '8.8441e+05', '-0.35', '0.286'], dtype='object')
# R-squared score: 0.6553568804893448
# Index(['9', '50', '55', '8.8441e+05', '0.978', '-1.093'], dtype='object')
# R-squared score: 0.6617492426731453
# Index(['10', '10.1', '15', '8.8441e+05', '0.566', '-1.131'], dtype='object')
# R-squared score: 0.6726046487445432
# Index(['9', '0', '45', '8.8441e+05', '0.018', '0.743'], dtype='object')
# R-squared score: 0.6079702257942766
# Index(['10', '39', '25', '8.8441e+05', '0.543', '-0.843'], dtype='object')
# R-squared score: 0.6218219689733304
# Index(['9', '11', '15', '8.8441e+05', '0.383', '-0.511'], dtype='object')
# R-squared score: 0.6416730608809029
# Index(['10', '22', '15', '8.8441e+05', '0.391', '-0.238'], dtype='object')
# R-squared score: 0.6588754251405329
# Index(['9', '14', '55', '8.8441e+05', '-0.381', '0.538'], dtype='object')
# R-squared score: 0.6814689656957847
# Index(['10', '6', '25', '8.8441e+05', '-0.383', '0.18'], dtype='object')
# R-squared score: 0.6029075791874183
# Index(['8', '32', '5', '8.8441e+05', '-0.054', '-0.18'], dtype='object')
# R-squared score: -0.056235044179049565
# Index(['9', '1', '55', '8.8441e+05', '-0.367', '0.443'], dtype='object')
# R-squared score: 0.6751315583352815
# Index(['9', '24', '45', '8.8441e+05', '-0.319', '0.077'], dtype='object')
# R-squared score: 0.6901626802244524
# Index(['8', '14', '45', '8.8441e+05', '-0.557', '0.155'], dtype='object')
# R-squared score: -0.0922558884327489
# Index(['8', '38', '55', '8.8441e+05', '-0.413', '-0.466'], dtype='object')
# R-squared score: 0.38125148804972164
# Index(['10', '31', '35', '8.8441e+05', '-0.2', '0.469'], dtype='object')
# R-squared score: 0.6098910041766004
# Index(['9', '44', '45', '8.8441e+05', '-0.454', '0.192'], dtype='object')
# R-squared score: 0.6906036564901148
# Index(['9', '9.1', '15', '8.8441e+05', '-0.351', '-0.209'], dtype='object')
# R-squared score: 0.6576503516633434
# Index(['9', '48', '5', '8.8441e+05', '0.147', '-0.94'], dtype='object')
# R-squared score: 0.7127150736287878
# Index(['9', '52', '35', '8.8441e+05', '-1.182', '0.972'], dtype='object')
# R-squared score: 0.6747731232084518
# Index(['9', '4', '35', '8.8441e+05', '0.705', '-0.386'], dtype='object')
# R-squared score: 0.7199965973811125
# Index(['9', '16', '25', '8.8441e+05', '0.314', '-0.045'], dtype='object')
# R-squared score: 0.6992160591503156
# Index(['9', '4', '25', '8.8441e+05', '-0.933', '1.173'], dtype='object')
# R-squared score: 0.6919799325452223
# Index(['9', '55', '15', '8.8441e+05', '-0.536', '0.931'], dtype='object')
# R-squared score: 0.6467647990561876
# Index(['9', '53', '5', '8.8441e+05', '0.114', '-0.462'], dtype='object')
# R-squared score: 0.6505916372498511
# Index(['10', '21', '15', '8.8441e+05', '-0.764', '1.635'], dtype='object')
# R-squared score: 0.616531679466594
# Index(['9', '58', '35', '8.8441e+05', '0.332', '-0.66'], dtype='object')
# R-squared score: 0.6294666670197645
# Index(['8', '59', '5', '8.8441e+05', '-0.281', '0.805'], dtype='object')
# R-squared score: 0.6299916454598247
# Index(['8', '42', '25', '8.8441e+05', '0.09', '-0.407'], dtype='object')
# R-squared score: 0.4754846683780418
# Index(['10', '1', '55', '8.8441e+05', '-0.425', '-0.104'], dtype='object')
# R-squared score: -0.15090237938256368
# Index(['10', '0', '25', '8.8441e+05', '0.086', '-0.273'], dtype='object')
# R-squared score: 0.6572570633845436
# Index(['9', '58', '5', '8.8441e+05', '0.55', '-0.355'], dtype='object')
# R-squared score: 0.5877139571743641
# Index(['8', '56', '15', '8.8441e+05', '-1.089', '0.599'], dtype='object')
# R-squared score: 0.6393094131534198
# Index(['8', '43', '55', '8.8441e+05', '-0.5', '0.23'], dtype='object')
# R-squared score: 0.5075198626565912
# Index(['8', '33', '35', '8.8441e+05', '-0.165', '-0.409'], dtype='object')
# R-squared score: 0.1756764011283075
# Index(['10', '44', '55', '8.8441e+05', '1.534', '0.339'], dtype='object')
# R-squared score: 0.23743271312237557
# Index(['9', '4', '5', '8.8441e+05', '0.012', '-1.022'], dtype='object')
# R-squared score: 0.6780303668751594
# Index(['10', '44', '45', '8.8441e+05', '1.126', '-0.037'], dtype='object')
# R-squared score: 0.27303902088565746
# Index(['10', '41', '15', '8.8441e+05', '0.324', '-0.694'], dtype='object')
# R-squared score: 0.44017564748672855
# Index(['8', '15', '15.1', '8.8441e+05', '0.331', '-0.516'], dtype='object')
# R-squared score: -0.1257811627695684
# Index(['10', '38', '15', '8.8441e+05', '0.415', '-0.67'], dtype='object')
# R-squared score: 0.6420371652606046
# Index(['10', '2', '55', '8.8441e+05', '-0.175', '0.9'], dtype='object')
# R-squared score: 0.4882546764282517
# Index(['8', '19', '25', '8.8441e+05', '0.311', '-0.206'], dtype='object')
# R-squared score: -0.1359825293720418
# Index(['10', '21', '35', '8.8441e+05', '0.037', '-0.264'], dtype='object')
# R-squared score: 0.640217526934951
# Index(['8', '49', '35', '8.8441e+05', '1.153', '-1.138'], dtype='object')
# R-squared score: 0.6556683134803007
# Index(['8', '44', '45', '8.8441e+05', '0.007', '0.695'], dtype='object')
# R-squared score: 0.6158866106376925
# Index(['8', '49', '5', '8.8441e+05', '0.537', '-0.507'], dtype='object')
# R-squared score: 0.5935669895964082
# Index(['10', '18', '15', '8.8441e+05', '-0.616', '0.288'], dtype='object')
# R-squared score: 0.633791603746156
# Index(['9', '13', '35', '8.8441e+05', '0.09', '-0.467'], dtype='object')
# R-squared score: 0.6888135629152596
# Index(['9', '1', '5', '8.8441e+05', '-1.841', '1.832'], dtype='object')
# R-squared score: 0.6713084435783884
# Index(['8', '55', '15', '8.8441e+05', '-0.405', '-0.482'], dtype='object')
# R-squared score: 0.6504852593837298
# Index(['8', '15', '35', '8.8441e+05', '0.186', '0.202'], dtype='object')
# R-squared score: -0.16105670431520114
# Index(['9', '13', '15', '8.8441e+05', '1.488', '-1.814'], dtype='object')
# R-squared score: 0.6865545140132644
# Index(['10', '18', '45', '8.8441e+05', '0.265', '0.033'], dtype='object')
# R-squared score: 0.5798042112926086
# Index(['10', '29', '35', '8.8441e+05', '0.019', '-0.156'], dtype='object')
# R-squared score: 0.6198251372063441
# Index(['10', '11', '15', '8.8441e+05', '-0.417', '1.031'], dtype='object')
# R-squared score: 0.6363236988431478
# Index(['9', '27', '25', '8.8441e+05', '0.251', '-1.342'], dtype='object')
# R-squared score: 0.6388628548648605
# Index(['9', '2', '5', '8.8441e+05', '0.984', '-0.783'], dtype='object')
# R-squared score: 0.6344491490929971
# Index(['9', '34', '15', '8.8441e+05', '0.602', '0.3'], dtype='object')
# R-squared score: 0.602800386717713
# Index(['10', '41', '35', '8.8441e+05', '1.159', '-1.655'], dtype='object')
# R-squared score: 0.3707570451472014
# Index(['9', '35', '25', '8.8441e+05', '-0.865', '1.426'], dtype='object')
# R-squared score: 0.6690176068513082
# Index(['10', '1', '15', '8.8441e+05', '-0.253', '0.417'], dtype='object')
# R-squared score: 0.6562689589454977
# Index(['9', '51', '45', '8.8441e+05', '-0.295', '0.723'], dtype='object')
# R-squared score: 0.5282326110031671
# Index(['9', '3', '45', '8.8441e+05', '0.465', '-0.032'], dtype='object')
# R-squared score: 0.6482871434433919
# Index(['9', '33', '35', '8.8441e+05', '0.114', '0.191'], dtype='object')
# R-squared score: 0.6507745732285448
# Index(['8', '17', '25', '8.8441e+05', '0.067', '-0.565'], dtype='object')
# R-squared score: -0.13682433541075256
# Index(['9', '4', '45', '8.8441e+05', '-0.197', '0.772'], dtype='object')
# R-squared score: 0.7033079472681089
# Index(['8', '55', '5', '8.8441e+05', '-0.7', '-0.026'], dtype='object')
# R-squared score: 0.610732103880674
# Index(['10', '22', '55', '8.8441e+05', '-0.826', '1.035'], dtype='object')
# R-squared score: 0.4217685223777956
# Index(['8', '26', '55', '8.8441e+05', '-0.192', '0.115'], dtype='object')
# R-squared score: 0.01596779535605719
# Index(['10', '20', '25', '8.8441e+05', '-0.129', '0.238'], dtype='object')
# R-squared score: 0.6459581208817359
# Index(['9', '19', '35', '8.8441e+05', '0.746', '-0.4'], dtype='object')
# R-squared score: 0.603080888326128
# Index(['9', '58', '15', '8.8441e+05', '0.549', '-0.852'], dtype='object')
# R-squared score: 0.6245342058651815
# Index(['9', '13', '5', '8.8441e+05', '-0.169', '-0.143'], dtype='object')
# R-squared score: 0.7169655468263052
# Index(['10', '28', '15', '8.8441e+05', '0.494', '-0.115'], dtype='object')
# R-squared score: 0.6439967979014753
# Index(['10', '2', '25', '8.8441e+05', '0.558', '-0.258'], dtype='object')
# R-squared score: 0.6363272991665223
# Index(['10', '18', '25', '8.8441e+05', '0.058', '-0.523'], dtype='object')
# R-squared score: 0.6366327252046668
# Index(['10', '32', '5', '8.8441e+05', '0.551', '-0.985'], dtype='object')
# R-squared score: 0.5609101193515775
# Index(['8', '28', '25', '8.8441e+05', '-0.295', '-0.016'], dtype='object')
# R-squared score: -0.04105656313743555
# Index(['9', '21', '45', '8.8441e+05', '0.073', '-0.51'], dtype='object')
# R-squared score: 0.6668421912213727
# Index(['8', '35', '5', '8.8441e+05', '0.23', '-0.017'], dtype='object')
# R-squared score: 0.11821017936148659
# Index(['10', '40', '5', '8.8441e+05', '-0.308', '0.148'], dtype='object')
# R-squared score: 0.42601975634697675
# Index(['10', '8', '35', '8.8441e+05', '0.871', '-1.311'], dtype='object')
# R-squared score: 0.6359183531350725
# Index(['10', '27', '35', '8.8441e+05', '-1.079', '1.217'], dtype='object')
# R-squared score: 0.6169555017568603
# Index(['9', '45', '5', '8.8441e+05', '1.067', '-1.117'], dtype='object')
# R-squared score: 0.627948625600249
# Index(['8', '52', '25', '8.8441e+05', '-0.964', '0.582'], dtype='object')
# R-squared score: 0.5931911333443932
# Index(['10', '35', '35.1', '8.8441e+05', '0.655', '-0.523'], dtype='object')
# R-squared score: 0.5570136392877155
# Index(['10', '39', '35', '8.8441e+05', '-0.203', '-0.24'], dtype='object')
# R-squared score: 0.5806767842812222
# Index(['8', '21', '5', '8.8441e+05', '0.213', '-0.039'], dtype='object')
# R-squared score: -0.15675365454072554
# Index(['8', '35', '35.1', '8.8441e+05', '-0.007', '-0.25'], dtype='object')
# R-squared score: 0.2411636907666178
# Index(['10', '10.1', '45', '8.8441e+05', '-0.39', '0.087'], dtype='object')
# R-squared score: 0.6391792976141291
# Index(['8', '24', '25', '8.8441e+05', '-0.219', '0.223'], dtype='object')
# R-squared score: -0.095672249021582
# Index(['8', '16', '55', '8.8441e+05', '-0.301', '0.255'], dtype='object')
# R-squared score: -0.114216602672641
# Index(['9', '50', '25', '8.8441e+05', '-0.341', '0.54'], dtype='object')
# R-squared score: 0.6614103150753395
# Index(['8', '21', '35', '8.8441e+05', '0.263', '-0.366'], dtype='object')
# R-squared score: -0.10975018739924547
# Index(['10', '30', '25', '8.8441e+05', '0.767', '-0.246'], dtype='object')
# R-squared score: 0.6569748788650408
# Index(['10', '13', '35', '8.8441e+05', '0.226', '-0.537'], dtype='object')
# R-squared score: 0.6842934572971693
# Index(['9', '57', '35', '8.8441e+05', '-1.029', '1.151'], dtype='object')
# R-squared score: 0.6735585458612262
# Index(['10', '40', '55', '8.8441e+05', '0.316', '0.025'], dtype='object')
# R-squared score: 0.41261660815051004
# Index(['9', '8', '15', '8.8441e+05', '-0.504', '-0.127'], dtype='object')
# R-squared score: 0.652489929179747
# Index(['9', '0', '5', '8.8441e+05', '0.369', '-0.615'], dtype='object')
# R-squared score: 0.7249741491620046
# Index(['9', '16', '15', '8.8441e+05', '-0.913', '0.366'], dtype='object')
# R-squared score: 0.6678826290255467
# Index(['10', '2', '5', '8.8441e+05', '2.103', '-2.131'], dtype='object')
# R-squared score: 0.6769204888102595
# Index(['9', '32', '45', '8.8441e+05', '0.307', '0.155'], dtype='object')
# R-squared score: 0.6312570722228463
# Index(['9', '19', '5', '8.8441e+05', '-0.296', '1.015'], dtype='object')
# R-squared score: 0.578174878235425
# Index(['8', '44', '5', '8.8441e+05', '0.47', '-0.022'], dtype='object')
# R-squared score: 0.5463709016028571
# Index(['10', '28', '45', '8.8441e+05', '0.793', '-0.638'], dtype='object')
# R-squared score: 0.5806839647976163
# Index(['8', '28', '5', '8.8441e+05', '0.006', '-0.081'], dtype='object')
# R-squared score: -0.04460668243037946
# Index(['9', '23', '5', '8.8441e+05', '-0.966', '0.887'], dtype='object')
# R-squared score: 0.5993713995734747
# Index(['9', '15', '45', '8.8441e+05', '-1.004', '0.538'], dtype='object')
# R-squared score: 0.683430808417334
# Index(['9', '41', '5', '8.8441e+05', '0.532', '-0.441'], dtype='object')
# R-squared score: 0.6783893544975361
# Index(['9', '33', '25', '8.8441e+05', '0.443', '-0.297'], dtype='object')
# R-squared score: 0.6638755537568197
# Index(['10', '0', '15', '8.8441e+05', '0.635', '-0.897'], dtype='object')
# R-squared score: 0.6717425113293026
# Index(['10', '34', '15', '8.8441e+05', '1.009', '-0.993'], dtype='object')
# R-squared score: 0.6399238643011558
# Index(['9', '32', '5', '8.8441e+05', '-0.167', '0.063'], dtype='object')
# R-squared score: 0.6309944656426446
# Index(['10', '34', '55', '8.8441e+05', '-0.023', '0.565'], dtype='object')
# R-squared score: 0.34843959976814354
# Index(['9', '0', '55', '8.8441e+05', '0.263', '-0.394'], dtype='object')
# R-squared score: 0.6446223522295274
# Index(['8', '54', '35', '8.8441e+05', '-0.942', '1.226'], dtype='object')
# R-squared score: 0.6914237125870112
# Index(['10', '12', '25', '8.8441e+05', '-0.525', '1.261'], dtype='object')
# R-squared score: 0.6641488967698597
# Index(['9', '52', '25', '8.8441e+05', '-0.415', '0.274'], dtype='object')
# R-squared score: 0.6224039674922133
# Index(['10', '18', '35', '8.8441e+05', '-0.301', '0.324'], dtype='object')
# R-squared score: 0.6447102739736497
# Index(['10', '23', '15', '8.8441e+05', '0.718', '-0.766'], dtype='object')
# R-squared score: 0.35719839245915097
# Index(['10', '32', '25', '8.8441e+05', '-0.118', '0.286'], dtype='object')
# R-squared score: 0.6760118895407107
# Index(['9', '23', '25', '8.8441e+05', '-0.292', '1.147'], dtype='object')
# R-squared score: 0.6813288199635927
# Index(['10', '12', '15', '8.8441e+05', '0.285', '-0.068'], dtype='object')
# R-squared score: 0.5949173849784074
# Index(['9', '37', '45', '8.8441e+05', '0.26', '-0.844'], dtype='object')
# R-squared score: 0.5797355484622546
# Index(['9', '35', '15', '8.8441e+05', '-1.229', '1.596'], dtype='object')
# R-squared score: 0.6241238968082394
# Index(['9', '45', '25', '8.8441e+05', '-1.381', '1.957'], dtype='object')
# R-squared score: 0.6217752341260252
# Index(['8', '35', '55', '8.8441e+05', '-0.059', '0.029'], dtype='object')
# R-squared score: 0.2744661522806957
# Index(['9', '14', '45', '8.8441e+05', '-0.196', '0.227'], dtype='object')
# R-squared score: 0.6840657610482467
# Index(['8', '39', '35', '8.8441e+05', '-0.027', '-0.063'], dtype='object')
# R-squared score: 0.5266399241103465
# Index(['10', '28', '35', '8.8441e+05', '-0.218', '-0.536'], dtype='object')
# R-squared score: 0.6443408619969888
# Index(['8', '19', '35', '8.8441e+05', '1.569', '-0.204'], dtype='object')
# R-squared score: -0.17126829230256657
# Index(['9', '56', '45', '8.8441e+05', '0.596', '0.443'], dtype='object')
# R-squared score: 0.6718336806179827
# Index(['10', '13', '45', '8.8441e+05', '0.301', '-0.208'], dtype='object')
# R-squared score: 0.6925073229614342
# Index(['10', '23', '45', '8.8441e+05', '0.772', '-0.897'], dtype='object')
# R-squared score: 0.6791410092211413
# Index(['10', '31', '45', '8.8441e+05', '0.31', '0.188'], dtype='object')
# R-squared score: 0.5592509387349953
# Index(['9', '59', '45', '8.8441e+05', '-0.287', '0.477'], dtype='object')
# R-squared score: 0.6298930135506456
# Index(['9', '43', '25', '8.8441e+05', '-0.72', '1.836'], dtype='object')
# R-squared score: 0.6345140697641146
# Index(['9', '18', '55', '8.8441e+05', '0.223', '-0.693'], dtype='object')
# R-squared score: 0.6279970906216218
# Index(['10', '33', '15', '8.8441e+05', '0.365', '-0.725'], dtype='object')
# R-squared score: 0.6390536610884568
# Index(['10', '37', '15', '8.8441e+05', '-0.44', '0.582'], dtype='object')
# R-squared score: 0.6171599922380048
# Index(['9', '58', '45', '8.8441e+05', '1.31', '-1.989'], dtype='object')
# R-squared score: 0.6700626334871754
# Index(['9', '24', '55', '8.8441e+05', '0.561', '-0.544'], dtype='object')
# R-squared score: 0.60611813800868
# Index(['9', '55', '5', '8.8441e+05', '0.744', '-0.593'], dtype='object')
# R-squared score: 0.5687221991117886
# Index(['9', '53', '15', '8.8441e+05', '0.149', '0.098'], dtype='object')
# R-squared score: 0.6576110242581902
# Index(['9', '22', '35', '8.8441e+05', '-0.355', '1.071'], dtype='object')
# R-squared score: 0.6336126477566426
# Index(['10', '43', '15', '8.8441e+05', '-0.986', '-0.595'], dtype='object')
# R-squared score: 0.3984304671872193
# Index(['10', '33', '55', '8.8441e+05', '0.386', '-0.303'], dtype='object')
# R-squared score: -0.0911050963582023
# Index(['9', '54', '35', '8.8441e+05', '-0.512', '0.168'], dtype='object')
# R-squared score: 0.6322001696824782
# Index(['8', '45', '55', '8.8441e+05', '-0.814', '1.149'], dtype='object')
# R-squared score: 0.6042680326663801
# Index(['8', '18', '45', '8.8441e+05', '0.839', '0.498'], dtype='object')
# R-squared score: -0.08436649703561505
# Index(['8', '18', '55', '8.8441e+05', '-0.403', '-0.084'], dtype='object')
# R-squared score: -0.10910567775878333
# Index(['8', '51', '35', '8.8441e+05', '0.555', '-0.728'], dtype='object')
# R-squared score: 0.6340342382877182
# Index(['9', '54', '25', '8.8441e+05', '1.072', '-0.813'], dtype='object')
# R-squared score: 0.49277144075313095
# Index(['9', '36', '45', '8.8441e+05', '-0.705', '0.547'], dtype='object')
# R-squared score: 0.6534703025259871
# Index(['10', '7', '55', '8.8441e+05', '0.27', '0.051'], dtype='object')
# R-squared score: 0.5732103256584864
# Index(['9', '36', '15', '8.8441e+05', '-0.362', '0.569'], dtype='object')
# R-squared score: 0.6087978846433175
# Index(['9', '36', '35', '8.8441e+05', '-0.353', '0.369'], dtype='object')
# R-squared score: 0.6197792236897735
# Index(['10', '12', '5', '8.8441e+05', '-1.483', '0.931'], dtype='object')
# R-squared score: 0.6354651183860345
# Index(['9', '23', '45', '8.8441e+05', '0.001', '0.201'], dtype='object')
# R-squared score: 0.5708428032481785
# Index(['9', '50', '15', '8.8441e+05', '0.859', '-1.621'], dtype='object')
# R-squared score: 0.6799534512627471
# Index(['10', '27', '55', '8.8441e+05', '-1.305', '0.589'], dtype='object')
# R-squared score: 0.4966528711358621
# Index(['9', '25', '15', '8.8441e+05', '-0.42', '0.235'], dtype='object')
# R-squared score: 0.5310409661233595
# Index(['9', '30', '45', '8.8441e+05', '1.148', '-1.111'], dtype='object')
# R-squared score: 0.6951614731298406
# Index(['8', '18', '25', '8.8441e+05', '-0.278', '0.312'], dtype='object')
# R-squared score: -0.1453577154258925
# Index(['9', '39', '35', '8.8441e+05', '0.326', '-0.211'], dtype='object')
# R-squared score: 0.6157018332841573
# Index(['10', '41', '45', '8.8441e+05', '-0.393', '-0.309'], dtype='object')
# R-squared score: 0.3343427110410694
# Index(['10', '43', '5', '8.8441e+05', '0.827', '1.879'], dtype='object')
# R-squared score: 0.4302512467884222
# Index(['8', '21', '55', '8.8441e+05', '-0.628', '-0.166'], dtype='object')
# R-squared score: -0.16097605854368502
# Index(['8', '17', '35', '8.8441e+05', '-0.326', '-0.096'], dtype='object')
# R-squared score: -0.24259148391689944
# Index(['10', '37', '55', '8.8441e+05', '1.2', '-1.472'], dtype='object')
# R-squared score: 0.5935926165445078
# Index(['10', '35', '45', '8.8441e+05', '-0.057', '-0.893'], dtype='object')
# R-squared score: 0.15241857462922404
# Index(['9', '27', '55', '8.8441e+05', '0.984', '-1.1'], dtype='object')
# R-squared score: 0.5929137546264902
# Index(['9', '7', '15', '8.8441e+05', '0.596', '-0.359'], dtype='object')
# R-squared score: 0.6553561101538525
# Index(['8', '36', '15', '8.8441e+05', '-0.301', '0.051'], dtype='object')
# R-squared score: 0.417694474145918
# Index(['9', '47', '25', '8.8441e+05', '0.846', '-0.521'], dtype='object')
# R-squared score: 0.6589839384020195
# Index(['8', '51', '55', '8.8441e+05', '1.03', '-1.405'], dtype='object')
# R-squared score: 0.5802984157490667
# Index(['10', '27', '5', '8.8441e+05', '-0.357', '0.862'], dtype='object')
# R-squared score: 0.5770532576239787
# Index(['9', '47', '55', '8.8441e+05', '-0.006', '0.607'], dtype='object')
# R-squared score: 0.6246336273879751
# Index(['9', '29', '35', '8.8441e+05', '0.28', '-0.167'], dtype='object')
# R-squared score: 0.6195093372421647
# Index(['8', '29', '5', '8.8441e+05', '0.228', '0.501'], dtype='object')
# R-squared score: 0.07640611600579417
# Index(['10', '34', '5', '8.8441e+05', '0.083', '-0.609'], dtype='object')
# R-squared score: 0.6201065725226781
# Index(['9', '15', '5', '8.8441e+05', '1.067', '-2.257'], dtype='object')
# R-squared score: 0.7241916323132909
# Index(['10', '39', '55', '8.8441e+05', '-0.767', '0.564'], dtype='object')
# R-squared score: 0.35057092025789705
# Index(['10', '39', '15', '8.8441e+05', '0.669', '-0.612'], dtype='object')
# R-squared score: 0.5963315806286553
# Index(['10', '29', '45', '8.8441e+05', '-0.073', '0.136'], dtype='object')
# R-squared score: 0.5434277586042784
# Index(['9', '39', '25', '8.8441e+05', '1.533', '-1.573'], dtype='object')
# ...
# R-squared score: -0.001538678449137798
# Index(['8', '32', '3', '5.4066e+05', '0.283', '-0.161'], dtype='object')
# R-squared score: 0.16090048857645434
# Index(['8', '33', '13', '5.4066e+05', '-0.649', '0.52'], dtype='object')
# R-squared score: 0.09529027690374847
# Index(['8', '41', '53', '5.4066e+05', '-0.585', '0.525'], dtype='object')
# R-squared score: 0.2899531540001684
# Index(['8', '5', '13', '5.4066e+05', '-0.628', '0.585'], dtype='object')
# R-squared score: -0.058347499574817
# Index(['8', '25', '53', '5.4066e+05', '-0.283', '0.533'], dtype='object')
# R-squared score: 0.08451924650999076
# Index(['8', '37', '33', '5.4066e+05', '1.16', '-2.787'], dtype='object')
# R-squared score: 0.10974393312135733
# Index(['9', '43', '23', '5.4066e+05', '0.953', '1.285'], dtype='object')
# R-squared score: -0.13913886370739603
# Index(['8', '25', '13', '5.4066e+05', '-0.363', '-0.495'], dtype='object')
# R-squared score: 0.21837330420413015
# Index(['8', '27', '13', '5.4066e+05', '-0.464', '0.658'], dtype='object')
# R-squared score: 0.1913630797962459
# Index(['8', '26', '13', '5.4066e+05', '0.026', '-1.02'], dtype='object')
# R-squared score: 0.20844447178358694
# Index(['8', '4', '33', '5.4066e+05', '-0.055', '-0.386'], dtype='object')
# R-squared score: -0.03358526303464693
# Index(['8', '29', '53', '5.4066e+05', '0.138', '0.093'], dtype='object')
# R-squared score: 0.08761869031415681
# Index(['8', '21', '23', '5.4066e+05', '-0.404', '0.515'], dtype='object')
# R-squared score: 0.1293902124075198
# Index(['8', '40', '43', '5.4066e+05', '0.184', '1.135'], dtype='object')
# R-squared score: 0.13732226807185932
# Index(['8', '26', '3', '5.4066e+05', '0.681', '-0.137'], dtype='object')
# R-squared score: 0.22617808408130446
# Index(['8', '43', '3', '5.4066e+05', '0.944', '-1.7'], dtype='object')
# R-squared score: 0.1595795844897573
# Index(['9', '11', '43', '5.4066e+05', '-0.235', '-0.957'], dtype='object')
# R-squared score: -0.04422805611775327
# Index(['9', '45', '3', '5.4066e+05', '-0.071', '0.102'], dtype='object')
# R-squared score: -0.16617097845211304
# Index(['8', '28', '13', '5.4066e+05', '0.449', '-0.385'], dtype='object')
# R-squared score: 0.1641826705336703
# Index(['8', '0', '43', '5.4066e+05', '0.405', '-0.352'], dtype='object')
# R-squared score: -0.0735265804973464
# Index(['9', '38', '53', '5.4066e+05', '-1.13', '0.41'], dtype='object')
# R-squared score: -0.23638671926674326
# Index(['7', '59', '23', '5.4066e+05', '0.315', '0.037'], dtype='object')
# R-squared score: -0.03315229703597078
# Index(['9', '32', '13', '5.4066e+05', '-0.522', '0.437'], dtype='object')
# R-squared score: -0.17531954221437118
# Index(['8', '51', '53', '5.4066e+05', '0.065', '-1.44'], dtype='object')
# R-squared score: -0.07623067199114386
# Index(['9', '44', '3', '5.4066e+05', '0.232', '-0.288'], dtype='object')
# R-squared score: -0.14931273910768605
# Index(['8', '34', '23', '5.4066e+05', '-0.737', '1.065'], dtype='object')
# R-squared score: 0.13325158229553002
# Index(['8', '17', '43', '5.4066e+05', '0.611', '-1.43'], dtype='object')
# R-squared score: 0.1315120245021797
# Index(['9', '46', '33', '5.4066e+05', '-1.071', '0.729'], dtype='object')
# R-squared score: -0.05567972201346527
# Index(['9', '39', '13', '5.4066e+05', '0.638', '0.514'], dtype='object')
# R-squared score: -0.21266536416980397
# Index(['8', '44', '53', '5.4066e+05', '0.306', '-1.604'], dtype='object')
# R-squared score: 0.13763700186289973
# Index(['7', '54', '33', '5.4066e+05', '0.229', '-0.243'], dtype='object')
# R-squared score: 0.026373508086935282
# Index(['9', '40', '3', '5.4066e+05', '0.303', '-0.601'], dtype='object')
# R-squared score: -0.26508965185738065
# Index(['8', '19', '23', '5.4066e+05', '0.219', '0.592'], dtype='object')
# R-squared score: 0.1201640027758143
# Index(['7', '47', '3', '5.4066e+05', '-0.169', '0.059'], dtype='object')
# R-squared score: 0.024003758278499654
# Index(['9', '12', '3', '5.4066e+05', '0.702', '-0.946'], dtype='object')
# R-squared score: -0.19987375576419675
# Index(['9', '1', '43', '5.4066e+05', '-0.11', '-2.801'], dtype='object')
# R-squared score: -0.07612194156563556
# Index(['9', '35', '43', '5.4066e+05', '0.387', '0.292'], dtype='object')
# R-squared score: -0.06207994820084628
# Index(['8', '24', '33', '5.4066e+05', '0.251', '-0.408'], dtype='object')
# R-squared score: 0.2144387141559475
# Index(['8', '53', '13', '5.4066e+05', '0.514', '0.726'], dtype='object')
# R-squared score: -0.10661767252942167
# Index(['9', '20', '43', '5.4066e+05', '-0.294', '0.123'], dtype='object')
# R-squared score: -0.13319563872336082
# Index(['8', '24', '23', '5.4066e+05', '0.493', '-0.324'], dtype='object')
# R-squared score: 0.28891037891839344
# Index(['9', '51', '23', '5.4066e+05', '-0.184', '1.854'], dtype='object')
# R-squared score: -0.013076819789968885
# Index(['8', '17', '13', '5.4066e+05', '0.52', '-0.251'], dtype='object')
# R-squared score: -0.007201047528387683
# Index(['9', '3', '53', '5.4066e+05', '0.604', '1.958'], dtype='object')
# R-squared score: -0.04737465194812418
# Index(['9', '25', '23', '5.4066e+05', '-0.755', '-1.334'], dtype='object')
# R-squared score: -0.11488176874088185
# Index(['9', '18', '43', '5.4066e+05', '1.025', '-0.199'], dtype='object')
# R-squared score: -0.15848397789176216
# Index(['8', '29', '33', '5.4066e+05', '-0.56', '1.288'], dtype='object')
# R-squared score: -0.000493285909954233
# Index(['7', '48', '13', '5.4066e+05', '0.021', '-0.132'], dtype='object')
# R-squared score: 0.004195205786243439
# Index(['7', '43', '43.1', '5.4066e+05', '0.086', '-0.342'], dtype='object')
# R-squared score: -0.10947613654822663
# Index(['9', '18', '53', '5.4066e+05', '1.298', '-2.292'], dtype='object')
# R-squared score: -0.1366293295723766
# Index(['9', '51', '43', '5.4066e+05', '3.004', '-0.268'], dtype='object')
# R-squared score: -0.15181640408902153
# Index(['8', '52', '43', '5.4066e+05', '-0.033', '2.251'], dtype='object')
# R-squared score: -0.08409093521237376
# Index(['9', '16', '33', '5.4066e+05', '0.125', '0.404'], dtype='object')
# R-squared score: -0.16330026754698745
# Index(['8', '16', '33', '5.4066e+05', '-0.591', '-0.27'], dtype='object')
# R-squared score: 0.0642452469641851
# Index(['7', '43', '13', '5.4066e+05', '-0.007', '0.177'], dtype='object')
# R-squared score: -0.058906489674108053
# Index(['8', '25', '3', '5.4066e+05', '-0.194', '-0.676'], dtype='object')
# R-squared score: 0.20300805629764118
# Index(['9', '32', '43', '5.4066e+05', '1.272', '0.609'], dtype='object')
# R-squared score: -0.05653445483363684
# Index(['9', '30', '23', '5.4066e+05', '0.015', '0.935'], dtype='object')
# R-squared score: -0.17289273302072594
# Index(['9', '52', '13', '5.4066e+05', '1.445', '-0.833'], dtype='object')
# R-squared score: -0.15608879570423406
# Index(['8', '54', '13', '5.4066e+05', '-0.649', '3.855'], dtype='object')
# R-squared score: -0.03517761422038945
# Index(['7', '45', '23', '5.4066e+05', '0.317', '-0.692'], dtype='object')
# R-squared score: 0.05784796766476785
# Index(['7', '50', '13', '5.4066e+05', '-0.088', '-0.41'], dtype='object')
# R-squared score: -0.15506895548503863
# Index(['9', '25', '53', '5.4066e+05', '-0.739', '1.195'], dtype='object')
# R-squared score: -0.2839292952770447
# Index(['8', '0', '13', '5.4066e+05', '0.371', '-0.117'], dtype='object')
# R-squared score: -0.07652642870829984
# Index(['8', '52', '33', '5.4066e+05', '-0.305', '1.05'], dtype='object')
# R-squared score: -0.06954952619692634
# Index(['9', '35', '13', '5.4066e+05', '0.04', '-0.834'], dtype='object')
# R-squared score: -0.10445790689029955
# Index(['9', '15', '33', '5.4066e+05', '-0.661', '1.975'], dtype='object')
# R-squared score: -0.10933366627972263
# Index(['8', '11', '43', '5.4066e+05', '-0.275', '-0.686'], dtype='object')
# R-squared score: -0.041344997501899794
# Index(['9', '7', '53', '5.4066e+05', '0.884', '1.788'], dtype='object')
# R-squared score: -0.22487717144028418
# Index(['7', '49', '13', '5.4066e+05', '0.737', '-0.729'], dtype='object')
# R-squared score: 0.04986938408710917
# Index(['8', '37', '13', '5.4066e+05', '0.777', '-2.549'], dtype='object')
# R-squared score: 0.15223053642204887
# Index(['8', '16', '13', '5.4066e+05', '0.018', '-0.119'], dtype='object')
# R-squared score: 0.026350060567619793
# Index(['7', '45', '33', '5.4066e+05', '-0.198', '0.398'], dtype='object')
# R-squared score: -0.027471220651141826
# Index(['8', '48', '13', '5.4066e+05', '-0.139', '-0.968'], dtype='object')
# R-squared score: -0.035039530488277126
# Index(['7', '57', '33', '5.4066e+05', '0.282', '-0.174'], dtype='object')
# R-squared score: -0.09289506483685339
# Index(['8', '23', '13', '5.4066e+05', '0.091', '-0.404'], dtype='object')
# R-squared score: 0.18610197267108575
# Index(['8', '12', '3', '5.4066e+05', '0.022', '0.066'], dtype='object')
# R-squared score: -0.05512603569430308
# Index(['8', '38', '3', '5.4066e+05', '-0.914', '0.341'], dtype='object')
# R-squared score: 0.08628816626023228
# Index(['8', '46', '23', '5.4066e+05', '-0.217', '-0.127'], dtype='object')
# R-squared score: 0.05410647884766573
# Index(['9', '19', '13', '5.4066e+05', '0.43', '0.708'], dtype='object')
# R-squared score: -0.14566092560016353
# Index(['8', '14', '23', '5.4066e+05', '-0.546', '0.248'], dtype='object')
# R-squared score: 0.0656795565203313
# Index(['8', '12', '33', '5.4066e+05', '0.491', '-0.455'], dtype='object')
# R-squared score: 0.004728162603111041
# Index(['9', '44', '43', '5.4066e+05', '-0.126', '-0.11'], dtype='object')
# R-squared score: -0.10279188238938564
# Index(['9', '10', '23', '5.4066e+05', '-1.01', '2.092'], dtype='object')
# R-squared score: -0.1991654694588516
# Index(['9', '13', '53', '5.4066e+05', '0.029', '0.042'], dtype='object')
# R-squared score: -0.16816007571736624
# Index(['9', '50', '3', '5.4066e+05', '-0.83', '0.746'], dtype='object')
# R-squared score: -0.005096963887703643
# Index(['8', '37', '3', '5.4066e+05', '0.569', '-1.453'], dtype='object')
# R-squared score: 0.052367637727371075
# Index(['9', '4', '23', '5.4066e+05', '-0.662', '0.981'], dtype='object')
# R-squared score: -0.15917454977551215
# Index(['9', '42', '13', '5.4066e+05', '0.394', '0.341'], dtype='object')
# R-squared score: -0.24915569334595866
# Index(['9', '21', '3', '5.4066e+05', '0.175', '-0.671'], dtype='object')
# R-squared score: -0.03707818443378108
# Index(['7', '51', '53', '5.4066e+05', '0.104', '-0.268'], dtype='object')
# R-squared score: -0.08128498613104207
# Index(['8', '44', '33', '5.4066e+05', '-0.711', '0.197'], dtype='object')
# R-squared score: 0.07597726323018894
# Index(['7', '51', '43', '5.4066e+05', '-0.042', '-0.262'], dtype='object')
# R-squared score: -0.05683687733734999
# Index(['8', '10', '3', '5.4066e+05', '-0.311', '-0.628'], dtype='object')
# R-squared score: 0.010285117593094695
# Index(['8', '48', '33', '5.4066e+05', '-0.127', '-1.533'], dtype='object')
# R-squared score: -0.026275837110145694
# Index(['8', '27', '53', '5.4066e+05', '0.18', '-0.686'], dtype='object')
# R-squared score: 0.21117658874768974
# Index(['9', '14', '13', '5.4066e+05', '0.917', '0.692'], dtype='object')
# R-squared score: -0.13472849115377183
# Index(['7', '56', '53', '5.4066e+05', '0.295', '-0.271'], dtype='object')
# R-squared score: -0.08953722316248358
# Index(['9', '43', '53', '5.4066e+05', '0.25', '-0.279'], dtype='object')
# R-squared score: -0.1965356703181338
# Index(['8', '1', '3', '5.4066e+05', '-0.408', '0.291'], dtype='object')
# R-squared score: -0.07999877723097115
# Index(['8', '43', '33', '5.4066e+05', '0.516', '-0.686'], dtype='object')
# R-squared score: 0.13989961541259688
# Index(['8', '20', '33', '5.4066e+05', '0.286', '-0.546'], dtype='object')
# R-squared score: 0.18744281693461273
# Index(['8', '46', '13', '5.4066e+05', '0.947', '-0.893'], dtype='object')
# R-squared score: 0.02930893356994657
# Index(['8', '45', '23', '5.4066e+05', '-0.662', '0.914'], dtype='object')
# R-squared score: 0.12248308004693853
# Index(['9', '28', '43', '5.4066e+05', '-0.645', '-1.252'], dtype='object')
# R-squared score: -0.290199251173076
# Index(['8', '5', '43', '5.4066e+05', '-0.444', '0.676'], dtype='object')
# R-squared score: -0.05202406679782978
# Index(['9', '9.1', '43', '5.4066e+05', '0.158', '-1.858'], dtype='object')
# R-squared score: -0.2151654145423476
# Index(['7', '48', '53', '5.4066e+05', '0.338', '0.285'], dtype='object')
# R-squared score: -0.05445461849325883
# Index(['8', '37', '53', '5.4066e+05', '-0.348', '1.792'], dtype='object')
# R-squared score: 0.08039525439682993
# Index(['7', '43', '53', '5.4066e+05', '-0.431', '0.331'], dtype='object')
# R-squared score: -0.0010179874735691818
# Index(['8', '59', '53', '5.4066e+05', '-1.801', '2.261'], dtype='object')
# R-squared score: -0.16403816812812644
# Index(['7', '46', '33', '5.4066e+05', '-0.468', '-0.007'], dtype='object')
# R-squared score: -0.060577957421376505
# Index(['9', '53', '3', '5.4066e+05', '0.068', '-0.973'], dtype='object')
# R-squared score: -0.1564739314938377
# Index(['8', '49', '3', '5.4066e+05', '0.271', '-0.431'], dtype='object')
# R-squared score: -0.1374554803705914
# Index(['7', '57', '3', '5.4066e+05', '-0.189', '0.678'], dtype='object')
# R-squared score: 0.018895523312122298
# Index(['9', '33', '33.1', '5.4066e+05', '-0.172', '0.725'], dtype='object')
# R-squared score: -0.27425281634608867
# Index(['7', '53', '33', '5.4066e+05', '0.978', '-0.24'], dtype='object')
# R-squared score: 0.03702397439236327
# Index(['8', '49', '43', '5.4066e+05', '-0.88', '1.932'], dtype='object')
# R-squared score: 0.012371773021884414
# Index(['9', '50', '23', '5.4066e+05', '-0.444', '1.158'], dtype='object')
# R-squared score: -0.05477651439402442
# Index(['8', '42', '23', '5.4066e+05', '-0.631', '0.224'], dtype='object')
# R-squared score: 0.24433334906484505
# Index(['7', '53', '43', '5.4066e+05', '0.231', '0.096'], dtype='object')
# R-squared score: -0.011378252186656557
# Index(['8', '0', '23', '5.4066e+05', '-0.289', '0.209'], dtype='object')
# R-squared score: -0.07785097553490705
# Index(['9', '8', '43', '5.4066e+05', '-0.194', '0.517'], dtype='object')
# R-squared score: -0.06587014165811444
# Index(['9', '4', '33', '5.4066e+05', '0.858', '0.361'], dtype='object')
# R-squared score: -0.020925673718676485
# Index(['8', '31', '33', '5.4066e+05', '-0.493', '2.697'], dtype='object')
# R-squared score: 0.13133999533669427
# Index(['7', '53', '23', '5.4066e+05', '-0.265', '0.233'], dtype='object')
# R-squared score: 0.0005734569642700249
# Index(['7', '55', '23', '5.4066e+05', '-0.87', '0.528'], dtype='object')
# R-squared score: 0.006326469072833185
# Index(['7', '56', '23', '5.4066e+05', '0.036', '-0.114'], dtype='object')
# R-squared score: -0.06236643458983204
# Index(['8', '25', '33', '5.4066e+05', '-0.369', '0.263'], dtype='object')
# R-squared score: 0.2483273868778303
# Index(['7', '41', '33', '5.4066e+05', '0.142', '-0.188'], dtype='object')
# R-squared score: 0.05919405096857733
# Index(['7', '50', '23', '5.4066e+05', '-0.187', '0.362'], dtype='object')
# R-squared score: -0.10569570055503141
# Index(['9', '25', '13', '5.4066e+05', '-0.205', '-0.803'], dtype='object')
# R-squared score: -0.12545866013407014
# Index(['9', '6', '23', '5.4066e+05', '-0.301', '0.072'], dtype='object')
# R-squared score: -0.07926665738408833
# Index(['8', '28', '23', '5.4066e+05', '-0.487', '1.278'], dtype='object')
# R-squared score: 0.1920878558808018
# Index(['8', '55', '23', '5.4066e+05', '-1.188', '2.185'], dtype='object')
# R-squared score: -0.1006279891014843
# Index(['7', '43', '33', '5.4066e+05', '0.256', '-0.357'], dtype='object')
# R-squared score: -0.01499520243792496
# Index(['9', '24', '33', '5.4066e+05', '0.078', '0.405'], dtype='object')
# R-squared score: -0.13004859883259945
# Index(['8', '56', '13', '5.4066e+05', '0.601', '-1.603'], dtype='object')
# R-squared score: -0.016332767834247974
# Index(['8', '16', '23', '5.4066e+05', '-0.383', '0.645'], dtype='object')
# R-squared score: 0.1432309884238967
# Index(['9', '40', '43', '5.4066e+05', '0.572', '-0.578'], dtype='object')
# R-squared score: -0.0958155254911841
# Index(['9', '34', '23', '5.4066e+05', '0.551', '-0.805'], dtype='object')
# R-squared score: -0.1401351081886122
# Index(['7', '54', '13', '5.4066e+05', '-0.119', '0.279'], dtype='object')
# R-squared score: 0.00826540607519699
# Index(['9', '7', '33', '5.4066e+05', '-0.145', '-0.792'], dtype='object')
# R-squared score: -0.0913123297764824

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def read_csv_files(directories):
    """
    Read all of the CSV files in the specified directories.

    Args:
        directories: A list of directories, each containing CSV files.

    Returns:
        A dictionary of DataFrames, where keys are the directories and values are the corresponding DataFrames.
    """

    dataframes = {}
    for directory in directories:
        csv_files = os.listdir(directory)
        dfs = []
        for csv_file in csv_files:
            dataframe = pd.read_csv(os.path.join(directory, csv_file))
            dfs.append(dataframe)
        dataframes[directory] = dfs

    return dataframes
def plot_rul_prediction(data):
    """
    Plot the RUL predictions against the true RUL values over cycles.

    Args:
        data: DataFrame containing the predicted and true RUL values.
    """

    plt.figure(figsize=(10, 6))

    # Create a new column 'Cycle' representing the cycle number for each row
    data['Cycle'] = range(1, len(data) + 1)

    # Plot True RUL and Predicted RUL over cycles
    plt.plot(data['Cycle'], data['True RUL'], label='True RUL', marker='*')
    plt.plot(data['Cycle'], data['Predicted RUL'], label='Predicted RUL', marker='.')

    plt.xlabel('Cycle')
    plt.ylabel('RUL')
    plt.title('True RUL vs. Predicted RUL over Cycles')
    plt.legend()
    plt.grid(True)
    plt.show()


def train_main():
    # List of directories containing the CSV files for each bearing set
    directories = [
        "/content/drive/MyDrive/fsm/Test_set/Bearing2_6",
        "/content/drive/MyDrive/fsm/Test_set/Bearing2_3",
        "/content/drive/MyDrive/fsm/Test_set/Bearing2_4",
        "/content/drive/MyDrive/fsm/Test_set/Bearing2_5",
        "/content/drive/MyDrive/fsm/Test_set/Bearing2_7"
    ]
    dataframes_dict = read_csv_files(directories)

    # Loop over the CSV files and train a model on each one
    for directory, dataframes in dataframes_dict.items():
        for i, dataframe in enumerate(dataframes):
            # Process each DataFrame, such as preprocessing, model training, etc.
            # Use 'directory' variable to keep track of the current bearing set.
            pass

        # Print column names to find the correct name of the target variable (RUL) column
        print(data.columns)

        # Assume the target variable is in the last column (index -1)
        target_column_index = -1
        X = data.drop(data.columns[target_column_index], axis=1)
        y = data[data.columns[target_column_index]]

        # Initialize the imputer with the desired strategy (e.g., mean, median, most frequent)
        imputer = SimpleImputer(strategy='mean')

        # Fit the imputer on the data and transform
        X_imputed = imputer.fit_transform(X)

        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

        # Train the RUL prediction model
        rul_model = train_rul_model(X_train, y_train)

        # Evaluate the model's performance on the test set (e.g., using mean squared error)
        score = rul_model.score(X_test, y_test)
        print("R-squared score:", score)

        # Add the predicted RUL values to the DataFrame
        data['Predicted RUL'] = rul_model.predict(X_imputed)
        data['True RUL'] = y

    return data

if __name__ == "__main__":
    data = train_main()
    plot_rul_prediction(data)
# Out:
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
print(data.columns)
# Out:
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')

# %%
print(data.head(20))
# Out:
#     10  19  11  6.1879e+05  0.172  -0.033  Predicted RUL  True RUL  Cycle
# 0   10  19  11    618830.0  0.133  -0.092           1.99         1      1
# 1   10  19  11    618870.0 -0.242  -0.178           2.24         2      2
# 2   10  19  11    618910.0 -0.040  -0.282           2.88         3      3
# 3   10  19  11    618940.0 -0.314   0.625           3.91         4      4
# 4   10  19  11    618980.0 -0.015  -0.107           5.02         5      5
# 5   10  19  11    619020.0  0.323  -0.159           6.00         6      6
# 6   10  19  11    619060.0 -0.003   0.026           6.84         7      7
# 7   10  19  11    619100.0  0.154  -0.039           7.80         8      8
# 8   10  19  11    619140.0 -0.014  -0.166           8.65         9      9
# 9   10  19  11    619180.0  0.227  -0.337           9.82        10     10
# 10  10  19  11    619220.0  0.077   0.418          11.12        11     11
# 11  10  19  11    619260.0  0.077  -0.149          11.94        12     12
# 12  10  19  11    619300.0 -0.179  -0.163          12.84        13     13
# 13  10  19  11    619340.0  0.149  -0.047          14.18        14     14
# 14  10  19  11    619370.0 -0.013   0.227          14.88        15     15
# 15  10  19  11    619410.0  0.093   0.361          15.65        16     16
# 16  10  19  11    619450.0  0.041  -0.674          17.12        17     17
# 17  10  19  11    619490.0 -0.079   0.223          17.88        18     18
# 18  10  19  11    619530.0 -0.047   0.153          18.96        19     19
# 19  10  19  11    619570.0  0.108  -0.100          19.73        20     20
