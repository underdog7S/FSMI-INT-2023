# %%
import os
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def read_csv_files(directories):
    """
    Read all of the CSV files in the specified directories.

    Args:
        directories: A comma-separated string of directories that contain the CSV files.

    Returns:
        A list of DataFrames, one for each CSV file.
    """

    dataframes = []
    for directory in directories.split(','):
        csv_files = os.listdir(directory.strip())
        for csv_file in csv_files:
            if csv_file.lower().endswith('.csv'):
                dataframe = pd.read_csv(os.path.join(directory.strip(), csv_file))
                dataframes.append(dataframe)

    return dataframes

def train_rul_model(X_train, y_train):
    """
    Train a Random Forest Regressor model on the given data.

    Args:
        X_train: The feature matrix for training.
        y_train: The target variable vector for training.

    Returns:
        The trained Random Forest Regressor model.
    """

    # Create and train the Random Forest Regressor
    rul_model = RandomForestRegressor(random_state=42)
    rul_model.fit(X_train, y_train)

    return rul_model

def main():
    # Get the list of CSV files in the directory
    directory = "/content/drive/MyDrive/fsm/Learning_set/Bearing1_1,/content/drive/MyDrive/fsm/Learning_set/Bearing1_2"
    csv_files = read_csv_files(directory)

    # Loop over the CSV files and train a model on each one
    for data in csv_files:
        # Print column names to find the correct name of the target variable (RUL) column
        print(data.columns)

        # Assume the target variable is in the last column (index -1)
        target_column_index = -1
        X = data.drop(data.columns[target_column_index], axis=1)
        y = data[data.columns[target_column_index]]

        # Initialize the imputer with the desired strategy (e.g., mean, median, most frequent)
        imputer = SimpleImputer(strategy='mean')

        # Fit the imputer on the data and transform
        X_imputed = imputer.fit_transform(X)

        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

        # Train the RUL prediction model and get the trained model
        rul_model = train_rul_model(X_train, y_train)

        # Evaluate the model's performance on the test set (e.g., using R-squared score)
        score = rul_model.score(X_test, y_test)
        print("R-squared score:", score)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Index(['10', '28', '59', '65664', '-0.213', '-0.574'], dtype='object')
# R-squared score: -0.16863921839437146
# Index(['11', '9', '29', '65664', '-0.41', '-0.115'], dtype='object')
# R-squared score: -0.1198678063266847
# Index(['11', '57', '19', '65664', '0.192', '0.07'], dtype='object')
# R-squared score: -0.2957559278031736
# Index(['12', '21', '29', '65664', '0.081', '0.041'], dtype='object')
# R-squared score: -0.18301412783758408
# Index(['12', '17', '39', '65664', '-0.224', '0.313'], dtype='object')
# R-squared score: -0.2809368558002341
# Index(['12', '9', '19', '65664', '-0.934', '0.352'], dtype='object')
# R-squared score: -0.1637466927397817
# Index(['17', '25', '39', '65664', '-1.298', '1.445'], dtype='object')
# R-squared score: -0.16046140913307538
# Index(['11', '46', '9', '65664', '0.17', '-0.143'], dtype='object')
# R-squared score: -0.11311809703488773
# Index(['12', '27', '9', '65664', '-0.281', '-0.027'], dtype='object')
# R-squared score: -0.22294135203433507
# Index(['14', '12', '19', '65664', '1.054', '-0.638'], dtype='object')
# R-squared score: -0.13650821028108773
# Index(['12', '38', '49', '65664', '-0.088', '0.367'], dtype='object')
# R-squared score: -0.19914815245840178
# Index(['13', '6', '29', '65664', '-0.104', '0.471'], dtype='object')
# R-squared score: -0.20652097656892754
# Index(['12', '21', '9', '65664', '0.594', '-0.141'], dtype='object')
# R-squared score: -0.18943889622728904
# Index(['14', '58', '59', '65664', '-0.959', '0.184'], dtype='object')
# R-squared score: -0.2744829706737142
# Index(['15', '57', '9', '65664', '0.706', '-0.253'], dtype='object')
# R-squared score: -0.15820374977677232
# Index(['16', '30', '29', '65664', '0.73', '0.141'], dtype='object')
# R-squared score: -0.1697955413825396
# Index(['16', '38', '19', '65664', '1.479', '0.632'], dtype='object')
# R-squared score: -0.1612387753830049
# Index(['17', '12', '39', '65664', '-0.33', '-0.82'], dtype='object')
# R-squared score: -0.16131634058254063
# Index(['11', '33', '29', '65664', '0.051', '-0.704'], dtype='object')
# R-squared score: -0.14972093350625792
# Index(['12', '2', '49', '65664', '-0.315', '-0.065'], dtype='object')
# R-squared score: -0.15197410173519144
# Index(['10', '3', '39', '65664', '-0.646', '-0.239'], dtype='object')
# R-squared score: -0.06585458487017859
# Index(['14', '13', '9', '65664', '0.143', '-0.153'], dtype='object')
# R-squared score: -0.19735888608106245
# Index(['14', '49', '19', '65664', '-0.75', '0.301'], dtype='object')
# R-squared score: -0.29920843798661334
# Index(['13', '41', '39', '65664', '-0.894', '-0.146'], dtype='object')
# R-squared score: -0.18573996047708263
# Index(['13', '50', '19', '65664', '0.227', '-0.985'], dtype='object')
# R-squared score: -0.12895229595077673
# Index(['12', '55', '9', '65664', '-0.139', '0.086'], dtype='object')
# R-squared score: -0.23931411400832792
# Index(['11', '17', '19', '65664', '0.098', '0.27'], dtype='object')
# R-squared score: -0.2392544897678648
# Index(['14', '26', '39', '65664', '0.333', '0.243'], dtype='object')
# R-squared score: -0.14614355635669485
# Index(['13', '2', '49', '65664', '-0.12', '-0.465'], dtype='object')
# R-squared score: -0.13311191070610628
# Index(['13', '23', '49', '65664', '-0.04', '0.137'], dtype='object')
# R-squared score: -0.15051550155546578
# Index(['16', '38', '39', '65664', '0.773', '-0.266'], dtype='object')
# R-squared score: -0.2065644376479867
# Index(['13', '50', '49', '65664', '-0.523', '0.301'], dtype='object')
# R-squared score: -0.22617039550885099
# Index(['10', '37', '39', '65664', '0.241', '0.201'], dtype='object')
# R-squared score: -0.10337744378377933
# Index(['16', '50', '29', '65664', '0.462', '0.112'], dtype='object')
# R-squared score: -0.1738973317955006
# Index(['15', '5', '9', '65664', '0.976', '-0.102'], dtype='object')
# R-squared score: -0.24505416131431623
# Index(['11', '26', '49', '65664', '-0.084', '0.063'], dtype='object')
# R-squared score: -0.15393670362887946
# Index(['16', '31', '39', '65664', '-1.365', '0.647'], dtype='object')
# R-squared score: -0.1981148292688002
# Index(['11', '51', '59', '65664', '0.557', '-1.156'], dtype='object')
# R-squared score: -0.2984620995066849
# Index(['13', '44', '9', '65664', '0.567', '-1.225'], dtype='object')
# R-squared score: -0.22696163564183092
# Index(['10', '41', '9', '65664', '-0.056', '0.591'], dtype='object')
# R-squared score: -0.2626382390341735
# Index(['11', '22', '29', '65664', '-0.091', '0.557'], dtype='object')
# R-squared score: -0.08917660472890088
# Index(['10', '41', '29', '65664', '-0.165', '0.709'], dtype='object')
# R-squared score: -0.1926152899430269
# Index(['14', '41', '19', '65664', '0.12', '0.212'], dtype='object')
# R-squared score: -0.21942947963479553
# Index(['16', '37', '49', '65664', '0.243', '1.942'], dtype='object')
# R-squared score: -0.16460409935662046
# Index(['15', '58', '29', '65664', '-0.336', '0.178'], dtype='object')
# R-squared score: -0.2504620479881905
# Index(['16', '37', '59', '65664', '0.101', '-0.231'], dtype='object')
# R-squared score: -0.210539851614582
# Index(['11', '22', '39', '65664', '-0.066', '-0.156'], dtype='object')
# R-squared score: -0.11369016181781655
# Index(['15', '30', '29', '65664', '0.539', '-1.362'], dtype='object')
# R-squared score: -0.16223352082527898
# Index(['15', '50', '59', '65664', '-0.926', '0.474'], dtype='object')
# R-squared score: -0.2555242798095405
# Index(['12', '38', '9', '65664', '0.094', '0.152'], dtype='object')
# R-squared score: -0.09429967636271575
# Index(['10', '29', '19', '65664', '0.82', '-0.287'], dtype='object')
# R-squared score: -0.11556409948021851
# Index(['15', '23', '9', '65664', '0.303', '0.244'], dtype='object')
# R-squared score: -0.2278342465857035
# Index(['12', '9', '59', '65664', '-0.269', '-0.14'], dtype='object')
# R-squared score: -0.24616197968461995
# Index(['11', '2', '9', '65664', '0.238', '0.507'], dtype='object')
# R-squared score: -0.15908981415089896
# Index(['15', '41', '49', '65664', '-0.786', '0.291'], dtype='object')
# R-squared score: -0.16818872344556302
# Index(['14', '58', '29', '65664', '0.121', '0.187'], dtype='object')
# R-squared score: -0.33560762018988766
# Index(['12', '7', '19', '65664', '-0.225', '0.304'], dtype='object')
# R-squared score: -0.26025244888758436
# Index(['15', '15.1', '59', '65664', '3.919', '-0.443'], dtype='object')
# R-squared score: -0.24305039188489075
# Index(['14', '33', '49', '65664', '-0.619', '0.752'], dtype='object')
# R-squared score: -0.22701199550631923
# Index(['14', '17', '39', '65664', '-0.191', '0.196'], dtype='object')
# R-squared score: -0.30099947448137554
# Index(['17', '6', '29', '65664', '-0.132', '0.185'], dtype='object')
# R-squared score: -0.012676644474216126
# Index(['13', '28', '9', '65664', '-0.093', '-0.277'], dtype='object')
# R-squared score: -0.1708987511365263
# Index(['13', '53', '39', '65664', '-0.016', '0.462'], dtype='object')
# R-squared score: -0.16266196454142
# Index(['12', '34', '29', '65664', '0.472', '-0.044'], dtype='object')
# R-squared score: -0.21799965808663968
# Index(['11', '16', '19', '65664', '-0.465', '0.482'], dtype='object')
# R-squared score: -0.1994108440726059
# Index(['9', '46', '39', '65664', '-0.317', '-0.314'], dtype='object')
# R-squared score: -0.06571419298144376
# Index(['11', '10', '39', '65664', '-0.047', '-0.338'], dtype='object')
# R-squared score: -0.1350091217347289
# Index(['10', '12', '29', '65664', '-0.196', '-0.19'], dtype='object')
# R-squared score: -0.04698524253117653
# Index(['12', '55', '29', '65664', '0.017', '0.364'], dtype='object')
# R-squared score: -0.15693756385583724
# Index(['11', '53', '49', '65664', '-0.408', '0.205'], dtype='object')
# R-squared score: -0.23654578585409003
# Index(['13', '49', '49.1', '65664', '-0.255', '-0.023'], dtype='object')
# R-squared score: -0.1832899308431668
# Index(['15', '6', '19', '65664', '-0.725', '1.033'], dtype='object')
# R-squared score: -0.15464206534247538
# Index(['13', '17', '9', '65664', '0.035', '-0.458'], dtype='object')
# R-squared score: -0.26582674917551774
# Index(['16', '29', '19', '65664', '1.056', '-0.002'], dtype='object')
# R-squared score: -0.17300721191095336
# Index(['10', '52', '59', '65664', '0.493', '0.03'], dtype='object')
# R-squared score: -0.16772860920540222
# Index(['16', '37', '9', '65664', '0.768', '0.081'], dtype='object')
# R-squared score: -0.22779589447335669
# Index(['15', '28', '29', '65664', '0.084', '0.704'], dtype='object')
# R-squared score: -0.22539632266395615
# Index(['11', '57', '9', '65664', '-0.268', '0.187'], dtype='object')
# R-squared score: -0.10340688905396744
# Index(['9', '46', '19', '65664', '0.398', '-0.6'], dtype='object')
# R-squared score: -0.1511641982201819
# Index(['16', '37', '29', '65664', '-1.257', '0.748'], dtype='object')
# R-squared score: -0.2734936505274683
# Index(['12', '24', '19', '65664', '-0.389', '-0.273'], dtype='object')
# R-squared score: -0.1633173052003385
# Index(['10', '27', '49', '65664', '-0.233', '0.269'], dtype='object')
# R-squared score: -0.11013629177557016
# Index(['16', '43', '39', '65664', '0.39', '-0.303'], dtype='object')
# R-squared score: -0.16644502695217533
# Index(['12', '32', '9', '65664', '0.518', '-0.599'], dtype='object')
# R-squared score: -0.25591850891222867
# Index(['16', '6', '9', '65664', '-1.249', '0.07'], dtype='object')
# R-squared score: -0.13263753979372517
# Index(['13', '2', '19', '65664', '0.381', '-0.802'], dtype='object')
# R-squared score: -0.28364345087378484
# Index(['16', '27', '39', '65664', '1.469', '-0.2'], dtype='object')
# R-squared score: -0.16517624905328643
# Index(['16', '21', '59', '65664', '-1.195', '-0.387'], dtype='object')
# R-squared score: 0.01202389786914504
# Index(['16', '26', '49', '65664', '-1.119', '0.761'], dtype='object')
# R-squared score: -0.1942673312887957
# Index(['14', '31', '39', '65664', '-0.005', '0.592'], dtype='object')
# R-squared score: -0.2724920280187162
# Index(['11', '41', '39', '65664', '-0.13', '-0.12'], dtype='object')
# R-squared score: -0.1275209644559765
# Index(['10', '12', '49', '65664', '0.133', '0.177'], dtype='object')
# R-squared score: -0.18731357939321214
# Index(['14', '34', '29', '65664', '0.583', '-0.325'], dtype='object')
# R-squared score: -0.2060732515168342
# Index(['12', '47', '19', '65664', '0.001', '-0.076'], dtype='object')
# R-squared score: -0.2427342114114015
# Index(['14', '37', '19', '65664', '0.071', '-0.026'], dtype='object')
# R-squared score: -0.12894090728155305
# Index(['14', '18', '19', '65664', '0.76', '1.042'], dtype='object')
# R-squared score: -0.16998206858093345
# Index(['11', '20', '49', '65664', '-0.632', '0.122'], dtype='object')
# R-squared score: -0.21365987237283712
# Index(['12', '44', '39', '65664', '0.231', '-0.27'], dtype='object')
# R-squared score: -0.2382528864762561
# Index(['17', '11', '59', '65664', '0.259', '1.079'], dtype='object')
# R-squared score: -0.23019684729594836
# Index(['13', '9', '19', '65664', '-0.46', '0.336'], dtype='object')
# R-squared score: -0.19764526321323417
# Index(['11', '5', '19', '65664', '-0.286', '0.482'], dtype='object')
# R-squared score: -0.1969569276798122
# Index(['13', '46', '9', '65664', '0.296', '0.226'], dtype='object')
# R-squared score: -0.3327642696473143
# Index(['12', '40', '29', '65664', '0.566', '-0.349'], dtype='object')
# R-squared score: -0.22075225572582857
# Index(['17', '11', '9', '65664', '-1.096', '-0.282'], dtype='object')
# R-squared score: -0.17732494300793222
# Index(['9', '38', '46', '8.6566e+005', '-1.626', '-0.086'], dtype='object')
# R-squared score: -0.2792345286429756
# Index(['16', '12', '39', '65664', '-0.741', '0.024'], dtype='object')
# R-squared score: -0.2361390303330888
# Index(['14', '28', '29', '65664', '0.583', '0.14'], dtype='object')
# R-squared score: -0.24252825796005872
# Index(['12', '17', '29', '65664', '0.405', '0.157'], dtype='object')
# R-squared score: -0.1696931718598753
# Index(['11', '57', '59', '65664', '0.233', '0.049'], dtype='object')
# R-squared score: -0.17474166190417972
# Index(['13', '34', '9', '65664', '0.304', '0.033'], dtype='object')
# R-squared score: -0.2579026424724644
# Index(['17', '22', '19', '65664', '1.203', '0.628'], dtype='object')
# R-squared score: -0.23262209308536463
# Index(['16', '59', '49', '65664', '-0.051', '0.049'], dtype='object')
# R-squared score: -0.22884712511716865
# Index(['13', '14', '59', '65664', '0.385', '-0.164'], dtype='object')
# R-squared score: -0.20896848050859673
# Index(['16', '46', '19', '65664', '-0.327', '-0.193'], dtype='object')
# R-squared score: -0.29106358610799443
# Index(['16', '1', '9', '65664', '0.102', '0.325'], dtype='object')
# R-squared score: -0.13524755525093424
# Index(['16', '45', '29', '65664', '-0.147', '0.106'], dtype='object')
# R-squared score: -0.2766429171626179
# Index(['14', '57', '59', '65664', '0.31', '-0.355'], dtype='object')
# R-squared score: -0.4027394289798576
# Index(['11', '37', '29', '65664', '0.521', '-0.011'], dtype='object')
# R-squared score: -0.1598090036052464
# Index(['13', '29', '9', '65664', '-0.165', '0.469'], dtype='object')
# R-squared score: -0.22969515021754372
# Index(['13', '38', '49', '65664', '-0.3', '-0.371'], dtype='object')
# R-squared score: -0.26535446661941386
# Index(['15', '9', '29', '65664', '0.317', '-0.878'], dtype='object')
# R-squared score: -0.28305508217541875
# Index(['16', '47', '9', '65664', '0.314', '-1.277'], dtype='object')
# R-squared score: -0.23218079309518513
# Index(['12', '2', '9', '65664', '0.213', '-0.305'], dtype='object')
# R-squared score: -0.1324757687559006
# Index(['14', '1', '9', '65664', '-0.387', '-0.036'], dtype='object')
# R-squared score: -0.17646356784695505
# Index(['12', '35', '9', '65664', '0.033', '0.174'], dtype='object')
# R-squared score: -0.15394656241136295
# Index(['12', '22', '19', '65664', '-0.115', '-0.56'], dtype='object')
# R-squared score: -0.24879040793163165
# Index(['13', '53', '59', '65664', '-0.282', '0.659'], dtype='object')
# R-squared score: -0.27012536077469784
# Index(['17', '22', '49', '65664', '-4.27', '-2.664'], dtype='object')
# R-squared score: -0.11941506373976774
# Index(['13', '19', '49', '65664', '0.25', '0.437'], dtype='object')
# R-squared score: -0.24558626996672306
# Index(['14', '25', '39', '65664', '0.099', '-0.103'], dtype='object')
# R-squared score: -0.15839004229718334
# Index(['14', '4', '9', '65664', '1.01', '-0.681'], dtype='object')
# R-squared score: -0.17454262899670892
# Index(['13', '5', '59', '65664', '0.484', '-0.338'], dtype='object')
# R-squared score: -0.24910045334679687
# Index(['15', '1', '29', '65664', '0.904', '0.179'], dtype='object')
# R-squared score: -0.2554803399184775
# Index(['11', '17', '9', '65664', '-0.2', '-0.26'], dtype='object')
# R-squared score: -0.13941354283907637
# Index(['12', '52', '59', '65664', '-0.272', '-0.205'], dtype='object')
# R-squared score: -0.15326879325714904
# Index(['9', '46', '29', '65664', '0.427', '-0.217'], dtype='object')
# R-squared score: -0.15906595646944677
# Index(['13', '9', '29', '65664', '-0.316', '0.35'], dtype='object')
# R-squared score: -0.23772932290840765
# Index(['11', '31', '9', '65664', '-0.42', '-0.583'], dtype='object')
# R-squared score: -0.15599718824793474
# Index(['16', '32', '19', '65664', '-0.792', '-0.208'], dtype='object')
# R-squared score: -0.1693241956862852
# Index(['17', '8', '49', '65664', '-1.547', '-0.308'], dtype='object')
# R-squared score: -0.21390510109818517
# Index(['12', '31', '29', '65664', '0.576', '0.079'], dtype='object')
# R-squared score: -0.22549815459618516
# Index(['12', '6', '19', '65664', '-0.249', '-0.354'], dtype='object')
# R-squared score: -0.23803484850198608
# Index(['10', '4', '19', '65664', '-0.225', '0.978'], dtype='object')
# R-squared score: -0.12189678863206899
# Index(['15', '20', '9', '65664', '0.429', '0.12'], dtype='object')
# R-squared score: -0.21195942337646279
# Index(['10', '49', '9', '65664', '-0.103', '0.253'], dtype='object')
# R-squared score: -0.13132483056292044
# Index(['14', '53', '49', '65664', '0.602', '0.719'], dtype='object')
# R-squared score: -0.18127599790657256
# Index(['10', '19', '59', '65664', '-0.327', '-0.03'], dtype='object')
# R-squared score: -0.05112387104239957
# Index(['11', '47', '9', '65664', '0.332', '0.162'], dtype='object')
# R-squared score: -0.2392667122847183
# Index(['9', '58', '59', '65664', '0.147', '0.147.1'], dtype='object')
# R-squared score: -0.0038073282831569966
# Index(['12', '56', '39', '65664', '0.484', '-0.011'], dtype='object')
# R-squared score: -0.20300822825890497
# Index(['11', '27', '9', '65664', '0.364', '0.06'], dtype='object')
# R-squared score: -0.13977366653448042
# Index(['9', '59', '59.1', '65664', '0.223', '0.485'], dtype='object')
# R-squared score: -0.03099130554395302
# Index(['12', '23', '9', '65664', '-0.848', '0.248'], dtype='object')
# R-squared score: -0.10178521843622357
# Index(['14', '43', '59', '65664', '0.378', '0.018'], dtype='object')
# R-squared score: -0.142938746969407
# Index(['12', '55', '49', '65664', '-0.126', '0.082'], dtype='object')
# R-squared score: -0.21506774858866784
# Index(['16', '9', '19', '65664', '-0.605', '0.117'], dtype='object')
# R-squared score: -0.14518888819420384
# Index(['12', '39', '9', '65664', '-0.13', '-0.882'], dtype='object')
# R-squared score: -0.2369314871958248
# Index(['17', '5', '49', '65664', '-1.598', '-0.167'], dtype='object')
# R-squared score: -0.16014027429973998
# Index(['17', '0', '29', '65664', '0.892', '0.229'], dtype='object')
# R-squared score: -0.27389562377117027
# Index(['10', '50', '49', '65664', '-0.093', '0.093'], dtype='object')
# R-squared score: -0.12279035278957617
# Index(['10', '6', '39', '65664', '-0.071', '-0.2'], dtype='object')
# R-squared score: -0.07290482003792165
# Index(['9', '56', '59', '65664', '-0.311', '0.649'], dtype='object')
# R-squared score: -0.046017331188818345
# Index(['11', '50', '49', '65664', '0.001', '-0.395'], dtype='object')
# R-squared score: -0.20587415261008912
# Index(['15', '51', '9', '65664', '-0.138', '-1.017'], dtype='object')
# R-squared score: -0.19904978733097
# Index(['15', '42', '19', '65664', '2.817', '-0.32'], dtype='object')
# R-squared score: -0.22020071105563765
# Index(['14', '11', '49', '65664', '-0.025', '-0.504'], dtype='object')
# R-squared score: -0.15492318264504434
# Index(['15', '31', '29', '65664', '-0.166', '1.294'], dtype='object')
# R-squared score: -0.17452518368775838
# Index(['10', '29', '39', '65664', '-0.073', '0.295'], dtype='object')
# R-squared score: -0.1620216234435028
# Index(['14', '19', '49', '65664', '0.307', '0.929'], dtype='object')
# R-squared score: -0.16862117921899378
# Index(['15', '9', '49', '65664', '0.65', '-0.168'], dtype='object')
# R-squared score: -0.2782471020472428
# Index(['11', '0', '49', '65664', '0.021', '0.233'], dtype='object')
# R-squared score: -0.18684729594416405
# Index(['15', '16', '59', '65664', '-0.086', '-0.68'], dtype='object')
# R-squared score: -0.2076842846467415
# Index(['16', '44', '19', '65664', '-2.476', '0.369'], dtype='object')
# R-squared score: -0.26759322861595547
# Index(['14', '3', '29', '65664', '0.404', '-0.441'], dtype='object')
# R-squared score: -0.20540229038094227
# Index(['15', '9', '19', '65664', '-0.629', '-0.187'], dtype='object')
# R-squared score: -0.3152556082057152
# Index(['13', '58', '19', '65664', '0.046', '-0.53'], dtype='object')
# R-squared score: -0.24424331975417624
# Index(['14', '17', '9', '65664', '0.533', '-0.367'], dtype='object')
# R-squared score: -0.21692964249323388
# Index(['14', '57', '39', '65664', '0.091', '0.095'], dtype='object')
# R-squared score: -0.1718096080662419
# Index(['14', '21', '9', '65664', '0.602', '0.451'], dtype='object')
# R-squared score: -0.23344977722045424
# Index(['13', '43', '29', '65664', '-0.599', '0.576'], dtype='object')
# R-squared score: -0.2547330350593262
# Index(['12', '3', '49', '65664', '-0.062', '0.051'], dtype='object')
# R-squared score: -0.13505398896056242
# Index(['16', '41', '59', '65664', '2.073', '-1.525'], dtype='object')
# R-squared score: -0.26845133015772205
# Index(['14', '14.1', '29', '65664', '0.301', '-0.923'], dtype='object')
# R-squared score: -0.21843986009815586
# Index(['16', '11', '19', '65664', '0.003', '0.644'], dtype='object')
# R-squared score: -0.1724283816935417
# Index(['13', '12', '49', '65664', '-0.232', '-0.392'], dtype='object')
# R-squared score: -0.22973846624384975
# Index(['12', '48', '19', '65664', '-0.001', '0.095'], dtype='object')
# R-squared score: -0.16163608836202448
# Index(['16', '9', '39', '65664', '3.411', '0.372'], dtype='object')
# R-squared score: -0.17289326276439376
# Index(['17', '17.1', '29', '65664', '2.273', '0.704'], dtype='object')
# R-squared score: -0.17969997368606183
# Index(['13', '5', '49', '65664', '0.585', '0.03'], dtype='object')
# R-squared score: -0.19438043878487843
# Index(['15', '1', '19', '65664', '-0.748', '0.696'], dtype='object')
# R-squared score: -0.217988512832608
# Index(['10', '47', '9', '65664', '0.149', '0.32'], dtype='object')
# R-squared score: -0.14212662312024937
# Index(['15', '11', '9', '65664', '0.066', '0.653'], dtype='object')
# R-squared score: -0.13615509286751393
# Index(['15', '22', '59', '65664', '0.048', '0.107'], dtype='object')
# R-squared score: -0.14420932983418844
# Index(['14', '22', '59', '65664', '2.016', '-1.049'], dtype='object')
# R-squared score: -0.2145531417837805
# Index(['12', '32', '29', '65664', '-0.058', '-0.064'], dtype='object')
# R-squared score: -0.17243250057544612
# Index(['16', '5', '59', '65664', '0.443', '0.128'], dtype='object')
# R-squared score: -0.19765228664336343
# Index(['13', '14', '29', '65664', '0.076', '-0.191'], dtype='object')
# R-squared score: -0.24377723783260818
# Index(['15', '20', '19', '65664', '-0.11', '0.202'], dtype='object')
# R-squared score: -0.1793326060073237
# Index(['11', '59', '59.1', '65664', '-0.823', '0.508'], dtype='object')
# R-squared score: -0.08581412936835076
# Index(['14', '31', '49', '65664', '0.879', '-0.483'], dtype='object')
# R-squared score: -0.18500923426170535
# Index(['10', '34', '29', '65664', '-0.251', '-0.178'], dtype='object')
# R-squared score: -0.14583262458137436
# Index(['14', '5', '59', '65664', '-1.269', '0.124'], dtype='object')
# R-squared score: -0.23119485033119536
# Index(['17', '9', '49', '65664', '-1.933', '0.524'], dtype='object')
# R-squared score: -0.19450707682827173
# Index(['13', '4', '9', '65664', '0.486', '0.305'], dtype='object')
# R-squared score: -0.18781822726539188
# Index(['17', '16', '59', '65664', '0.967', '-0.017'], dtype='object')
# R-squared score: -0.11294094387908538
# Index(['9', '45', '39', '65664', '0.781', '-0.546'], dtype='object')
# R-squared score: -0.13303466964642885
# Index(['16', '50', '59', '65664', '-1.964', '-0.664'], dtype='object')
# R-squared score: -0.25696671720922315
# Index(['14', '15', '29', '65664', '0.437', '0.48'], dtype='object')
# R-squared score: -0.24148551849922373
# Index(['9', '53', '39', '65664', '-0.455', '-0.671'], dtype='object')
# R-squared score: -0.11560994494665078
# Index(['15', '30', '59', '65664', '-0.909', '0.088'], dtype='object')
# R-squared score: -0.2361954225303955
# Index(['12', '56', '9', '65664', '0.57', '-0.528'], dtype='object')
# R-squared score: -0.22609152737754612
# Index(['15', '19', '19.1', '65664', '0.009', '0.339'], dtype='object')
# R-squared score: -0.258773927664973
# Index(['11', '26', '9', '65664', '0.163', '0.152'], dtype='object')
# R-squared score: -0.21080290055748674
# Index(['13', '47', '39', '65664', '0.169', '-0.629'], dtype='object')
# R-squared score: -0.27353847443220936
# Index(['14', '36', '59', '65664', '0.761', '-0.301'], dtype='object')
# R-squared score: -0.22016918138529484
# Index(['13', '3', '9', '65664', '0.196', '0.499'], dtype='object')
# R-squared score: -0.18436357258244107
# Index(['10', '17', '19', '65664', '-0.173', '-0.103'], dtype='object')
# R-squared score: -0.05134328477376093
# Index(['9', '57', '19', '65664', '-1.15', '0.351'], dtype='object')
# R-squared score: -0.1783889259975835
# Index(['11', '47', '59', '65664', '-0.637', '0.209'], dtype='object')
# R-squared score: -0.1883079089688504
# Index(['14', '9', '59', '65664', '-0.963', '-0.128'], dtype='object')
# R-squared score: -0.23844938305945984
# Index(['16', '37', '39', '65664', '-0.145', '-0.132'], dtype='object')
# R-squared score: -0.23322661236794828
# Index(['10', '39', '49', '65664', '0.362', '-0.561'], dtype='object')
# R-squared score: -0.1408774257417782
# Index(['12', '3', '19', '65664', '-0.275', '-0.087'], dtype='object')
# R-squared score: -0.21865168944448898
# Index(['16', '28', '29', '65664', '-2.984', '-1.019'], dtype='object')
# R-squared score: -0.045273090112609715
# Index(['17', '19', '29', '65664', '1.331', '0.18'], dtype='object')
# R-squared score: -0.3193312177105627
# Index(['17', '7', '9', '65664', '0.092', '-0.24'], dtype='object')
# R-squared score: -0.19681856389962848
# Index(['14', '48', '39', '65664', '0.32', '0.406'], dtype='object')
# R-squared score: -0.17157354899123156
# Index(['14', '37', '29', '65664', '-0.187', '-0.836'], dtype='object')
# R-squared score: -0.22601559537186655
# Index(['16', '0', '59', '65664', '-0.966', '-0.045'], dtype='object')
# R-squared score: -0.16148858553141587
# Index(['10', '33', '9', '65664', '-0.371', '0.485'], dtype='object')
# R-squared score: -0.16830371085291662
# Index(['15', '58', '9', '65664', '1.341', '0.247'], dtype='object')
# R-squared score: -0.2013725606629133
# Index(['15', '49', '59', '65664', '-0.137', '-0.701'], dtype='object')
# R-squared score: -0.05090390879083406
# Index(['11', '13', '59', '65664', '-0.108', '-0.01'], dtype='object')
# R-squared score: -0.17129873026308529
# Index(['10', '46', '9', '65664', '0.311', '-0.52'], dtype='object')
# R-squared score: -0.18855377821656982
# Index(['13', '58', '39', '65664', '0.644', '0.116'], dtype='object')
# R-squared score: -0.13823261321447133
# Index(['16', '58', '59', '65664', '0.12', '1.229'], dtype='object')
# R-squared score: -0.1710609750153702
# Index(['11', '29', '19', '65664', '0.006', '-0.319'], dtype='object')
# R-squared score: -0.39381336015973933
# Index(['16', '58', '29', '65664', '-0.373', '-1.462'], dtype='object')
# R-squared score: -0.19259741921659312
# Index(['13', '24', '29', '65664', '0.189', '0.162'], dtype='object')
# R-squared score: -0.18865062199117655
# Index(['13', '45', '59', '65664', '-0.371', '0.6'], dtype='object')
# R-squared score: -0.16277317737560915
# Index(['16', '23', '49', '65664', '1.365', '-0.601'], dtype='object')
# R-squared score: -0.19482428785769024
# Index(['16', '6', '39', '65664', '0.09', '-0.098'], dtype='object')
# R-squared score: -0.13741045062502266
# Index(['14', '35', '9', '65664', '0.283', '0.37'], dtype='object')
# R-squared score: -0.2928361340468346
# Index(['11', '57', '39', '65664', '0.31', '-0.349'], dtype='object')
# R-squared score: -0.22577223446404493
# Index(['14', '25', '49', '65664', '0.329', '0.456'], dtype='object')
# R-squared score: -0.3238117733332886
# Index(['11', '11.1', '19', '65664', '0.292', '0.541'], dtype='object')
# R-squared score: -0.1348359493204625
# Index(['14', '12', '49', '65664', '-0.152', '-0.044'], dtype='object')
# R-squared score: -0.19480545606281674
# Index(['15', '52', '59', '65664', '2.377', '-0.291'], dtype='object')
# R-squared score: -0.24512066769211027
# Index(['14', '57', '49', '65664', '-0.106', '-0.32'], dtype='object')
# R-squared score: -0.2407045866876314
# Index(['15', '47', '9', '65664', '-0.429', '-0.508'], dtype='object')
# R-squared score: -0.27993557325441754
# Index(['10', '14', '59', '65664', '0.406', '-0.037'], dtype='object')
# R-squared score: -0.277294965329306
# Index(['14', '35', '59', '65664', '-0.313', '-0.031'], dtype='object')
# R-squared score: -0.14436467179411894
# Index(['10', '8', '59', '65664', '0.625', '-0.313'], dtype='object')
# R-squared score: -0.053047793617665207
# Index(['11', '4', '9', '65664', '-0.456', '0.001'], dtype='object')
# R-squared score: -0.1777123071909359
# Index(['12', '25', '29', '65664', '-0.357', '0.081'], dtype='object')
# R-squared score: -0.19673829734318637
# Index(['10', '13', '9', '65664', '-0.036', '-0.096'], dtype='object')
# R-squared score: -0.05680310522428367
# Index(['15', '21', '19', '65664', '0.423', '-0.623'], dtype='object')
# R-squared score: -0.21018495585219243
# Index(['16', '17', '9', '65664', '1.421', '-0.074'], dtype='object')
# R-squared score: -0.12598286319037322
# Index(['10', '35', '19', '65664', '-0.51', '0.032'], dtype='object')
# R-squared score: -0.14331356069058643
# Index(['13', '26', '19', '65664', '-0.321', '-0.311'], dtype='object')
# R-squared score: -0.1721219191753074
# Index(['10', '24', '59', '65664', '-0.129', '0.179'], dtype='object')
# R-squared score: -0.04811988677089518
# Index(['12', '3', '39', '65664', '-0.345', '0.357'], dtype='object')
# R-squared score: -0.16230317094419244
# Index(['10', '23', '49', '65664', '0.088', '0.046'], dtype='object')
# R-squared score: -0.09016680211860284
# Index(['13', '23', '29', '65664', '0.281', '-0.123'], dtype='object')
# R-squared score: -0.22276311262056714
# Index(['13', '46', '29', '65664', '0.2', '0.256'], dtype='object')
# R-squared score: -0.2622456214939899
# Index(['11', '35', '59', '65664', '0.339', '-0.579'], dtype='object')
# R-squared score: -0.3306881065591505
# Index(['14', '13', '49', '65664', '0.32', '-0.211'], dtype='object')
# R-squared score: -0.18841155278757005
# Index(['11', '23', '29', '65664', '-0.177', '-0.104'], dtype='object')
# R-squared score: -0.2070376997859722
# Index(['11', '45', '59', '65664', '0.005', '-0.036'], dtype='object')
# R-squared score: -0.1073965472634808
# Index(['11', '38', '19', '65664', '-0.099', '0.228'], dtype='object')
# R-squared score: -0.12432973713806694
# Index(['12', '58', '39', '65664', '0.518', '0.191'], dtype='object')
# R-squared score: -0.3028049128242418
# Index(['13', '12', '19', '65664', '0.69', '-0.015'], dtype='object')
# R-squared score: -0.1787534876352439
# Index(['10', '54', '39', '65664', '0.546', '-0.088'], dtype='object')
# R-squared score: -0.07271151608692383
# Index(['15', '44', '19', '65664', '0.041', '0.077'], dtype='object')
# R-squared score: -0.10784618979615912
# Index(['14', '33', '59', '65664', '0.212', '-0.257'], dtype='object')
# R-squared score: -0.22323429748616386
# Index(['16', '44', '59', '65664', '-0.809', '0.39'], dtype='object')
# R-squared score: -0.30881263902096734
# Index(['13', '56', '19', '65664', '-0.858', '0.131'], dtype='object')
# R-squared score: -0.22173332808431367
# Index(['16', '41', '9', '65664', '0.687', '-1.15'], dtype='object')
# R-squared score: -0.2805792336011834
# Index(['11', '41', '49', '65664', '-0.282', '-0.011'], dtype='object')
# R-squared score: 0.018379859326225656
# Index(['10', '53', '19', '65664', '0.028', '-0.077'], dtype='object')
# R-squared score: -0.22965672803920234
# Index(['11', '33', '59', '65664', '-0.184', '-0.147'], dtype='object')
# R-squared score: -0.17043777285107065
# Index(['13', '18', '59', '65664', '-0.039', '0.019'], dtype='object')
# R-squared score: -0.24795208530117785
# Index(['11', '0', '29', '65664', '-0.257', '0.47'], dtype='object')
# R-squared score: -0.15294882467978899
# Index(['17', '20', '19', '65664', '-3.49', '1.295'], dtype='object')
# R-squared score: -0.12091080672322119
# Index(['16', '52', '9', '65664', '0.635', '-0.681'], dtype='object')
# R-squared score: -0.31046644431205017
# Index(['17', '17.1', '39', '65664', '-1.287', '0.376'], dtype='object')
# R-squared score: -0.3068465471801054
# Index(['15', '43', '39', '65664', '-2.162', '-0.075'], dtype='object')
# R-squared score: -0.21665411762872688
# Index(['10', '48', '59', '65664', '-0.538', '0.253'], dtype='object')
# R-squared score: -0.15652423859539288
# Index(['10', '39', '19', '65664', '-0.251', '-0.225'], dtype='object')
# R-squared score: -0.11412146992571226
# Index(['9', '42', '39', '65664', '0.849', '-0.505'], dtype='object')
# R-squared score: -0.09333473186862773
# Index(['11', '35', '9', '65664', '0.089', '0.049'], dtype='object')
# R-squared score: -0.19954641388595062
# Index(['16', '40', '59', '65664', '2.628', '-0.57'], dtype='object')
# R-squared score: -0.22685118509640856
# Index(['14', '59', '49', '65664', '0.447', '0.221'], dtype='object')
# R-squared score: -0.26448938586486515
# Index(['15', '38', '59', '65664', '0.212', '0.82'], dtype='object')
# R-squared score: -0.14361657849647602
# Index(['10', '2', '39', '65664', '0.238', '0.194'], dtype='object')
# R-squared score: -0.15302191936028775
# Index(['12', '43', '19', '65664', '-0.458', '-0.692'], dtype='object')
# R-squared score: -0.12566388075606638
# Index(['17', '2', '9', '65664', '0.965', '-0.323'], dtype='object')
# R-squared score: -0.21198851988702216
# Index(['15', '12', '59', '65664', '0.733', '-0.659'], dtype='object')
# R-squared score: -0.275831931066306
# Index(['15', '34', '59', '65664', '-0.074', '-0.12'], dtype='object')
# R-squared score: -0.2328817135638117
# Index(['11', '10', '49', '65664', '-0.356', '-0.397'], dtype='object')
# R-squared score: -0.17989060436395032
# Index(['11', '18', '19', '65664', '0.046', '-0.637'], dtype='object')
# R-squared score: -0.1948660134812028
# Index(['11', '46', '19', '65664', '-0.033', '0.403'], dtype='object')
# R-squared score: -0.1668725505286468
# Index(['10', '37', '59', '65664', '0.459', '0.236'], dtype='object')
# R-squared score: -0.11514987255686115
# Index(['11', '45', '9', '65664', '0.396', '0.209'], dtype='object')
# R-squared score: -0.12692609492583107
# Index(['15', '4', '39', '65664', '0.731', '-0.119'], dtype='object')
# R-squared score: -0.21352063710032643
# Index(['16', '12', '29', '65664', '0.859', '0.141'], dtype='object')
# R-squared score: -0.17077355032980046
# Index(['13', '15', '59', '65664', '-0.494', '0.083'], dtype='object')
# R-squared score: -0.20058629180359056
# Index(['17', '23', '39', '65664', '1.648', '0.769'], dtype='object')
# R-squared score: -0.33499084801199563
# Index(['10', '53', '39', '65664', '0.08', '0.646'], dtype='object')
# R-squared score: -0.14452122273890922
# Index(['15', '16', '9', '65664', '0.693', '0.134'], dtype='object')
# R-squared score: -0.14668634642639966
# Index(['15', '44', '9', '65664', '0.265', '-0.375'], dtype='object')
# R-squared score: -0.1922394664962752
# Index(['12', '0', '39', '65664', '0.083', '0.146'], dtype='object')
# R-squared score: -0.21713286127111653
# Index(['14', '55', '59', '65664', '-0.44', '0.346'], dtype='object')
# R-squared score: -0.17474534524598595
# Index(['10', '54', '49', '65664', '-0.383', '0.973'], dtype='object')
# R-squared score: -0.19212450989117946
# Index(['14', '32', '29', '65664', '0.695', '-0.366'], dtype='object')
# R-squared score: -0.2854889961923932
# Index(['12', '40', '49', '65664', '-0.19', '0.646'], dtype='object')
# R-squared score: -0.17338691996220867
# Index(['15', '31', '9', '65664', '0.483', '-0.412'], dtype='object')
# R-squared score: -0.24947772320394668
# Index(['15', '1', '59', '65664', '0.374', '-0.481'], dtype='object')
# R-squared score: -0.2029039033326714
# Index(['11', '2', '19', '65664', '-0.285', '-0.627'], dtype='object')
# R-squared score: -0.12819374100603653
# Index(['11', '6', '19', '65664', '-0.345', '0.032'], dtype='object')
# R-squared score: -0.17274825779966374
# Index(['11', '9', '9.1', '65664', '0.09', '-0.441'], dtype='object')
# R-squared score: -0.0843346694528131
# Index(['11', '49', '39', '65664', '-0.067', '0.032'], dtype='object')
# R-squared score: -0.2919139319244759
# Index(['12', '2', '19', '65664', '-0.283', '-0.136'], dtype='object')
# R-squared score: -0.2531352885484335
# Index(['13', '54', '29', '65664', '-0.817', '-0.423'], dtype='object')
# R-squared score: -0.3175139154641067
# Index(['17', '23', '59', '65664', '2.19', '1.429'], dtype='object')
# R-squared score: -0.17290937020378516
# Index(['14', '24', '49', '65664', '-0.039', '0.552'], dtype='object')
# R-squared score: -0.16608803345547263
# Index(['9', '50', '19', '65664', '-0.388', '-0.708'], dtype='object')
# R-squared score: -0.1824447565664078
# Index(['15', '18', '39', '65664', '-1.095', '0.017'], dtype='object')
# R-squared score: -0.19025265326801177
# Index(['16', '49', '19', '65664', '1.074', '-0.176'], dtype='object')
# R-squared score: -0.23144097338477465
# Index(['16', '52', '59', '65664', '3.034', '-0.775'], dtype='object')
# R-squared score: -0.1717050417162107
# Index(['15', '16', '19', '65664', '1.397', '-0.369'], dtype='object')
# R-squared score: -0.20204114752975322
# Index(['15', '35', '29', '65664', '-0.707', '1.574'], dtype='object')
# R-squared score: -0.1982146994515246
# Index(['9', '45', '49', '65664', '0.299', '0.545'], dtype='object')
# R-squared score: -0.07334648033501723
# Index(['12', '0', '29', '65664', '-0.011', '-0.473'], dtype='object')
# R-squared score: -0.13185447500590874
# Index(['10', '1', '9', '65664', '-0.071', '0.315'], dtype='object')
# R-squared score: -0.1759258630572318
# Index(['13', '45', '19', '65664', '0.216', '0.49'], dtype='object')
# R-squared score: -0.23775554889572703
# Index(['10', '54', '19', '65664', '0.491', '-0.676'], dtype='object')
# R-squared score: -0.18675226758076002
# Index(['15', '29', '49', '65664', '2.289', '-0.394'], dtype='object')
# R-squared score: -0.1353562641495154
# Index(['16', '18', '9', '65664', '-1.149', '0.377'], dtype='object')
# R-squared score: -0.11856205761213001
# Index(['13', '12', '39', '65664', '-0.122', '0.574'], dtype='object')
# R-squared score: -0.16653390809138213
# Index(['14', '54', '39', '65664', '-0.264', '0.663'], dtype='object')
# R-squared score: -0.23039580513081992
# Index(['14', '30', '9', '65664', '-0.02', '-0.989'], dtype='object')
# R-squared score: -0.17981632844013595
# Index(['17', '24', '39', '65664', '0.253', '6.029'], dtype='object')
# R-squared score: -0.11762712357476679
# Index(['10', '39', '59', '65664', '0.092', '0.259'], dtype='object')
# R-squared score: -0.13253790039261015
# Index(['10', '36', '59', '65664', '0.392', '-0.732'], dtype='object')
# R-squared score: -0.13260157605351797
# Index(['14', '59', '19', '65664', '-1.722', '0.495'], dtype='object')
# R-squared score: -0.22992732365919988
# Index(['9', '56', '19', '65664', '-0.38', '0.2'], dtype='object')
# R-squared score: -0.11927479276182007
# Index(['15', '10', '19', '65664', '0.541', '0.019'], dtype='object')
# R-squared score: -0.20937758765615078
# Index(['12', '59', '59.1', '65664', '-0.228', '0.077'], dtype='object')
# R-squared score: -0.285699731767852
# Index(['16', '7', '19', '65664', '-0.643', '0.005'], dtype='object')
# R-squared score: -0.15112415710383065
# Index(['14', '36', '19', '65664', '-0.195', '-0.142'], dtype='object')
# R-squared score: -0.18089713893055337
# Index(['16', '10', '59', '65664', '0.688', '0.258'], dtype='object')
# R-squared score: -0.1945510064190441
# Index(['17', '4', '9', '65664', '0.701', '-0.169'], dtype='object')
# R-squared score: -0.23385103885361658
# Index(['14', '35', '39', '65664', '-0.313', '0.461'], dtype='object')
# R-squared score: -0.1762333748847007
# Index(['12', '51', '59', '65664', '-0.184', '0.517'], dtype='object')
# R-squared score: -0.2263133112700062
# Index(['10', '58', '19', '65664', '-0.214', '-0.208'], dtype='object')
# R-squared score: -0.14643951998441151
# Index(['17', '21', '19', '65664', '-4.334', '0.267'], dtype='object')
# R-squared score: -0.06661235962900403
# Index(['11', '38', '49', '65664', '-0.291', '0.383'], dtype='object')
# R-squared score: -0.09757952587933572
# Index(['17', '0', '39', '65664', '0.509', '0.038'], dtype='object')
# R-squared score: -0.26253872481057217
# Index(['14', '37', '39', '65664', '-0.418', '0.063'], dtype='object')
# R-squared score: -0.2128545470513481
# Index(['16', '22', '9', '65664', '-0.555', '0.291'], dtype='object')
# R-squared score: -0.1722039597544096
# Index(['10', '55', '49', '65664', '0.066', '-0.376'], dtype='object')
# R-squared score: -0.14652919532585007
# Index(['16', '20', '29', '65664', '-1.421', '0.412'], dtype='object')
# R-squared score: -0.16980021948840363
# Index(['10', '18', '9', '65664', '-0.075', '-0.527'], dtype='object')
# R-squared score: -0.11174195263187037
# Index(['12', '37', '59', '65664', '0.525', '-0.464'], dtype='object')
# R-squared score: -0.2464253728635888
# Index(['11', '46', '29', '65664', '0.075', '-0.09'], dtype='object')
# R-squared score: -0.266801731894279
# Index(['15', '0', '29', '65664', '0.588', '0.345'], dtype='object')
# R-squared score: -0.25254216832435694
# Index(['12', '20', '29', '65664', '-0.162', '-0.128'], dtype='object')
# R-squared score: -0.17513763525799209
# Index(['11', '59', '29', '65664', '0.401', '-0.143'], dtype='object')
# R-squared score: -0.1771155451307438
# Index(['13', '33', '49', '65664', '-0.996', '-0.095'], dtype='object')
# R-squared score: -0.20044661278805864
# Index(['15', '23', '49', '65664', '0.928', '0.263'], dtype='object')
# R-squared score: -0.19760456751526445
# Index(['12', '52', '49', '65664', '0.31', '-0.276'], dtype='object')
# R-squared score: -0.24396987582919238
# Index(['14', '21', '59', '65664', '0.266', '0.337'], dtype='object')
# R-squared score: -0.21922024585194633
# Index(['10', '6', '49', '65664', '-0.176', '-0.815'], dtype='object')
# R-squared score: -0.13918495263993336
# Index(['11', '40', '39', '65664', '-0.055', '-0.451'], dtype='object')
# R-squared score: -0.10369140880718497
# Index(['15', '5', '49', '65664', '-0.327', '0.328'], dtype='object')
# R-squared score: -0.2250259133154917
# Index(['17', '1', '9', '65664', '0.206', '-0.504'], dtype='object')
# R-squared score: -0.1752103829010616
# Index(['14', '33', '9', '65664', '1.008', '-0.589'], dtype='object')
# R-squared score: -0.28676200681215036
# Index(['13', '12', '29', '65664', '-0.004', '0.208'], dtype='object')
# R-squared score: -0.24509801494307815
# Index(['16', '55', '29', '65664', '0.413', '0.324'], dtype='object')
# R-squared score: -0.25311482629055315
# Index(['16', '54', '49', '65664', '0.402', '-0.716'], dtype='object')
# R-squared score: -0.06201397547598275
# Index(['16', '33', '9', '65664', '-0.545', '-0.634'], dtype='object')
# R-squared score: -0.17794805480455778
# Index(['11', '31', '39', '65664', '0.257', '-0.484'], dtype='object')
# R-squared score: -0.18070477881348923
# Index(['17', '10', '9', '65664', '-0.519', '0.698'], dtype='object')
# R-squared score: -0.2218370097220128
# Index(['11', '48', '59', '65664', '0.148', '-0.286'], dtype='object')
# R-squared score: -0.187566083025813
# Index(['16', '40', '29', '65664', '3.651', '-0.778'], dtype='object')
# R-squared score: -0.24928795648706958
# Index(['11', '43', '19', '65664', '-0.283', '0.333'], dtype='object')
# R-squared score: -0.17943388134523297
# Index(['10', '15', '39', '65664', '-0.29', '0.319'], dtype='object')
# R-squared score: -0.1318466354990524
# Index(['13', '56', '59', '65664', '0.056', '0.297'], dtype='object')
# R-squared score: -0.2600247027398488
# Index(['14', '55', '39', '65664', '-0.652', '-0.218'], dtype='object')
# R-squared score: -0.2453343035340767
# Index(['15', '15.1', '39', '65664', '0.082', '-0.98'], dtype='object')
# R-squared score: -0.17164976853686387
# Index(['13', '8', '19', '65664', '0.563', '0.53'], dtype='object')
# R-squared score: -0.24906613290529722
# Index(['16', '10', '19', '65664', '-0.066', '-0.336'], dtype='object')
# R-squared score: -0.13038265634162882
# Index(['13', '34', '29', '65664', '0.269', '-0.337'], dtype='object')
# R-squared score: -0.2144697795240087
# Index(['11', '2', '49', '65664', '0.247', '-0.206'], dtype='object')
# R-squared score: -0.19827063177241167
# Index(['17', '13', '59', '65664', '0.73', '0.205'], dtype='object')
# R-squared score: -0.1647245214602835
# Index(['11', '30', '39', '65664', '-0.287', '0.477'], dtype='object')
# R-squared score: -0.17177760142019016
# Index(['16', '19', '29', '65664', '-0.982', '0.418'], dtype='object')
# R-squared score: -0.07056954014875072
# Index(['12', '26', '39', '65664', '-0.566', '-0.033'], dtype='object')
# R-squared score: -0.19963136324195818
# Index(['12', '18', '39', '65664', '-0.694', '0.09'], dtype='object')
# R-squared score: -0.2322212575492637
# Index(['13', '41', '49', '65664', '0.9', '-0.327'], dtype='object')
# R-squared score: -0.2314490908797866
# Index(['16', '23', '29', '65664', '-0.865', '0.229'], dtype='object')
# R-squared score: -0.17976286768351968
# Index(['13', '10', '59', '65664', '-0.125', '0.549'], dtype='object')
# R-squared score: -0.2112276862939626
# Index(['13', '32', '29', '65664', '0.256', '0.515'], dtype='object')
# R-squared score: -0.21809589658428719
# Index(['12', '23', '19', '65664', '0.339', '-0.132'], dtype='object')
# R-squared score: -0.19886870111448673
# Index(['13', '20', '9', '65664', '0.06', '-0.132'], dtype='object')
# R-squared score: -0.09261658681301199
# Index(['11', '43', '59', '65664', '-0.505', '0.361'], dtype='object')
# R-squared score: -0.15261545962385026
# Index(['11', '53', '19', '65664', '0.057', '-0.6'], dtype='object')
# R-squared score: -0.18857446289806412
# Index(['13', '32', '59', '65664', '0.416', '-0.23'], dtype='object')
# R-squared score: -0.14913198008770423
# Index(['11', '53', '59', '65664', '0.351', '-0.145'], dtype='object')
# R-squared score: -0.3074911134466294
# Index(['11', '47', '39', '65664', '0.59', '-0.194'], dtype='object')
# R-squared score: -0.21275415132236497
# Index(['16', '14', '29', '65664', '0.457', '0.666'], dtype='object')
# R-squared score: -0.1564196194260581
# Index(['9', '50', '9.1', '65664', '0.192', '-0.289'], dtype='object')
# R-squared score: -0.06944672635249471
# Index(['13', '37', '29', '65664', '-0.115', '-0.585'], dtype='object')
# R-squared score: -0.2069530450781627
# Index(['12', '29', '39', '65664', '-0.382', '0.006'], dtype='object')
# R-squared score: -0.23827828221274272
# Index(['13', '54', '9', '65664', '0.188', '-0.599'], dtype='object')
# R-squared score: -0.19969246833107102
# Index(['9', '42', '59', '65664', '0.555', '0.327'], dtype='object')
# R-squared score: 0.035571490881467605
# Index(['15', '17', '49', '65664', '-0.159', '-0.181'], dtype='object')
# R-squared score: -0.2740130179663911
# Index(['15', '16', '29', '65664', '1.454', '0.025'], dtype='object')
# R-squared score: -0.18343244097817313
# Index(['12', '34', '49', '65664', '0.463', '-0.488'], dtype='object')
# R-squared score: -0.17720871381967873
# Index(['10', '49', '49.1', '65664', '0.415', '-0.085'], dtype='object')
# R-squared score: -0.03459572113994169
# Index(['16', '2', '19', '65664', '1.274', '0.526'], dtype='object')
# R-squared score: -0.13871477374214503
# Index(['10', '52', '19', '65664', '-0.145', '-0.3'], dtype='object')
# R-squared score: -0.21927845660314627
# Index(['13', '38', '9', '65664', '0.342', '-0.235'], dtype='object')
# R-squared score: -0.1951851374615925
# Index(['16', '33', '19', '65664', '0.595', '0.053'], dtype='object')
# R-squared score: -0.16157962639580448
# Index(['15', '53', '9', '65664', '1.891', '-0.118'], dtype='object')
# R-squared score: -0.21393147590710537
# Index(['15', '58', '39', '65664', '-0.428', '-0.116'], dtype='object')
# R-squared score: -0.17278700658867518
# Index(['12', '15', '19', '65664', '-0.03', '0.194'], dtype='object')
# R-squared score: -0.18977045567550022
# Index(['15', '34', '29', '65664', '1.431', '0.328'], dtype='object')
# R-squared score: -0.10233441176926772
# Index(['12', '5', '29', '65664', '-0.172', '-0.243'], dtype='object')
# R-squared score: -0.18757795309390257
# Index(['12', '51', '9', '65664', '0.331', '-0.079'], dtype='object')
# R-squared score: -0.10937504483902294
# Index(['14', '16', '49', '65664', '0.646', '-1.236'], dtype='object')
# R-squared score: -0.16986651482621884
# Index(['16', '35', '29', '65664', '-1.657', '-0.404'], dtype='object')
# R-squared score: -0.15082483479030628
# Index(['15', '19', '9', '65664', '-0.304', '0.515'], dtype='object')
# R-squared score: -0.21387159222565222
# Index(['16', '8', '49', '65664', '0.041', '1.034'], dtype='object')
# R-squared score: -0.04468924318734491
# Index(['12', '25', '19', '65664', '0.201', '-0.244'], dtype='object')
# R-squared score: -0.20001480060352872
# Index(['14', '9', '49', '65664', '0.302', '-0.259'], dtype='object')
# R-squared score: -0.22258361713512254
# Index(['16', '4', '59', '65664', '-1.355', '0.489'], dtype='object')
# R-squared score: -0.13085582349320424
# Index(['11', '3', '19', '65664', '-0.119', '-0.17'], dtype='object')
# R-squared score: -0.18155517783995823
# Index(['15', '28', '39', '65664', '-1.119', '-0.186'], dtype='object')
# R-squared score: -0.2011104271175701
# Index(['13', '24', '39', '65664', '-0.122', '0.008'], dtype='object')
# R-squared score: -0.21573704991736808
# Index(['10', '8', '39', '65664', '0.247', '-1.119'], dtype='object')
# R-squared score: -0.1992112083053268
# Index(['13', '55', '59', '65664', '-0.14', '0.587'], dtype='object')
# R-squared score: -0.23844050424312546
# Index(['15', '45', '49', '65664', '-0.41', '0.839'], dtype='object')
# R-squared score: -0.15590992767270784
# Index(['16', '17', '19', '65664', '0.945', '-0.264'], dtype='object')
# R-squared score: -0.11785428034259438
# Index(['13', '36', '39', '65664', '0.511', '-0.634'], dtype='object')
# R-squared score: -0.2541174015083585
# Index(['12', '32', '39', '65664', '0.108', '0.032'], dtype='object')
# R-squared score: -0.2138917204345887
# ...
# R-squared score: -0.219818407461992
# Index(['9', '54', '5', '1.9691e+05', '-0.059', '0.683'], dtype='object')
# R-squared score: -0.1469281803899678
# Index(['10', '6', '5', '1.9691e+05', '-0.216', '0.355'], dtype='object')
# R-squared score: -0.044770804173469125
# Index(['10', '49', '35', '1.9691e+05', '0.66', '-0.308'], dtype='object')
# R-squared score: -0.08127062495896942
# Index(['8', '51', '15', '1.9691e+05', '0.062', '-0.492'], dtype='object')
# R-squared score: -0.12372756841589405
# Index(['8', '52', '35', '1.9691e+05', '-0.365', '0.45'], dtype='object')
# R-squared score: -0.20308541829246107
# Index(['9', '54', '55', '1.9691e+05', '-0.987', '0.163'], dtype='object')
# R-squared score: -0.1354843201942164
# Index(['10', '59', '5', '1.9691e+05', '-0.096', '0.23'], dtype='object')
# R-squared score: -0.1732688450386375
# Index(['10', '7', '45', '1.9691e+05', '-0.039', '-1.011'], dtype='object')
# R-squared score: -0.21209421201262613
# Index(['9', '27', '5', '1.9691e+05', '0.041', '-0.059'], dtype='object')
# R-squared score: 0.06682937277408552
# Index(['10', '48', '55', '1.9691e+05', '-0.022', '-0.021'], dtype='object')
# R-squared score: -0.24471759987641595
# Index(['9', '21', '25', '1.9691e+05', '0.259', '-0.244'], dtype='object')
# R-squared score: -0.2278939209439268
# Index(['9', '13', '25', '1.9691e+05', '0.358', '0.709'], dtype='object')
# R-squared score: -0.4894965341589266
# Index(['8', '52', '55', '1.9691e+05', '0.221', '-0.106'], dtype='object')
# R-squared score: -0.2037869046528462
# Index(['11', '11.1', '5', '1.9691e+05', '-0.451', '-1.396'], dtype='object')
# R-squared score: -0.2513424380006617
# Index(['9', '38', '5', '1.9691e+05', '0.056', '0.091'], dtype='object')
# R-squared score: -0.16332551181356125
# Index(['8', '50', '25', '1.9691e+05', '0.014', '-0.435'], dtype='object')
# R-squared score: -0.09413975280061138
# Index(['10', '3', '35', '1.9691e+05', '-0.025', '0.096'], dtype='object')
# R-squared score: -0.04038714399066756
# Index(['10', '1', '35', '1.9691e+05', '-0.383', '0.183'], dtype='object')
# R-squared score: -0.2504194543904539
# Index(['10', '53', '45', '1.9691e+05', '-0.027', '0.054'], dtype='object')
# R-squared score: -0.2896495582165368
# Index(['9', '32', '45', '1.9691e+05', '0.343', '-0.394'], dtype='object')
# R-squared score: -0.2661995327535349
# Index(['11', '6', '5', '1.9691e+05', '-0.438', '0.094'], dtype='object')
# R-squared score: -0.21722239166901547
# Index(['9', '27', '25', '1.9691e+05', '0.285', '-0.601'], dtype='object')
# R-squared score: -0.18950742544816124
# Index(['9', '11', '45', '1.9691e+05', '-0.339', '-0.454'], dtype='object')
# R-squared score: -0.308412591489192
# Index(['9', '15', '15.1', '1.9691e+05', '0.093', '-0.513'], dtype='object')
# R-squared score: -0.20200462917892215
# Index(['10', '0', '45', '1.9691e+05', '-0.018', '0.063'], dtype='object')
# R-squared score: -0.1862337591596157
# Index(['9', '2', '55', '1.9691e+05', '-0.304', '1.07'], dtype='object')
# R-squared score: -0.12159418083900486
# Index(['10', '43', '35', '1.9691e+05', '-0.139', '0.575'], dtype='object')
# R-squared score: -0.21052026642827038
# Index(['10', '56', '45', '1.9691e+05', '-0.259', '0.235'], dtype='object')
# R-squared score: -0.11362321191198999
# Index(['10', '2', '35', '1.9691e+05', '-0.05', '0.389'], dtype='object')
# R-squared score: -0.2299250491614302
# Index(['9', '44', '15', '1.9691e+05', '-0.061', '0.624'], dtype='object')
# R-squared score: -0.23288896007799176
# Index(['11', '8', '5', '1.9691e+05', '1.45', '1.203'], dtype='object')
# R-squared score: -0.21387751766048724
# Index(['11', '2', '5', '1.9691e+05', '0.107', '0.053'], dtype='object')
# R-squared score: -0.2612813796653495
# Index(['9', '46', '5', '1.9691e+05', '0.248', '-0.536'], dtype='object')
# R-squared score: -0.20291647633468846
# Index(['9', '49', '55', '1.9691e+05', '-0.059', '-0.658'], dtype='object')
# R-squared score: -0.15038174590469255
# Index(['11', '6', '35', '1.9691e+05', '0.805', '-0.576'], dtype='object')
# R-squared score: -0.13860111523616458
# Index(['10', '59', '15', '1.9691e+05', '0.124', '0.222'], dtype='object')
# R-squared score: -0.1723854922802739
# Index(['10', '12', '25', '1.9691e+05', '-0.048', '-0.102'], dtype='object')
# R-squared score: -0.21864614070115018
# Index(['11', '2', '15', '1.9691e+05', '0.63', '-0.332'], dtype='object')
# R-squared score: -0.27202845813628396
# Index(['8', '53', '45', '1.9691e+05', '0.208', '0.475'], dtype='object')
# R-squared score: -0.21398991841935455
# Index(['9', '27', '55', '1.9691e+05', '0.383', '0.276'], dtype='object')
# R-squared score: -0.20352275085973437
# Index(['9', '8', '25', '1.9691e+05', '0.087', '0.045'], dtype='object')
# R-squared score: -0.15379496524920322
# Index(['10', '2', '15', '1.9691e+05', '0.469', '-0.776'], dtype='object')
# R-squared score: -0.18789536495372428
# Index(['9', '4', '25', '1.9691e+05', '0.418', '0.17'], dtype='object')
# R-squared score: -0.22844704865810672
# Index(['10', '42', '55', '1.9691e+05', '-0.179', '0.58'], dtype='object')
# R-squared score: -0.21800387959345424
# Index(['10', '56', '35', '1.9691e+05', '0.017', '-0.05'], dtype='object')
# R-squared score: -0.2080122488817775
# Index(['9', '2', '15', '1.9691e+05', '0.295', '-0.126'], dtype='object')
# R-squared score: -0.18237505406979748
# Index(['9', '11', '5', '1.9691e+05', '-0.165', '-0.04'], dtype='object')
# R-squared score: -0.5248885013817133
# Index(['10', '51', '5', '1.9691e+05', '-0.594', '-0.195'], dtype='object')
# R-squared score: -0.1880547402797026
# Index(['9', '22', '25', '1.9691e+05', '0.129', '0.015'], dtype='object')
# R-squared score: -0.6346577445568102
# Index(['10', '36', '35', '1.9691e+05', '-0.071', '-0.275'], dtype='object')
# R-squared score: -0.23640829463020574
# Index(['9', '30', '5', '1.9691e+05', '-0.018', '0.191'], dtype='object')
# R-squared score: -0.5234060134182255
# Index(['9', '12', '15', '1.9691e+05', '0.433', '-0.255'], dtype='object')
# R-squared score: -0.255732390941829
# Index(['10', '47', '25', '1.9691e+05', '0.274', '-0.214'], dtype='object')
# R-squared score: -0.07557989756722483
# Index(['9', '19', '5', '1.9691e+05', '0.236', '0.07'], dtype='object')
# R-squared score: 0.1717305834563464
# Index(['10', '32', '25', '1.9691e+05', '0.185', '-0.131'], dtype='object')
# R-squared score: -0.08413578824195866
# Index(['9', '48', '55', '1.9691e+05', '-0.314', '0.314'], dtype='object')
# R-squared score: -0.20166237770034456
# Index(['9', '43', '55', '1.9691e+05', '-0.04', '0.993'], dtype='object')
# R-squared score: -0.27006747619023797
# Index(['10', '13', '45', '1.9691e+05', '0.144', '-0.47'], dtype='object')
# R-squared score: -0.6988317185823101
# Index(['11', '9', '5', '1.9691e+05', '-0.035', '2.305'], dtype='object')
# R-squared score: -0.1956942342873751
# Index(['11', '5', '45', '1.9691e+05', '0.702', '-0.02'], dtype='object')
# R-squared score: -0.27252544293666525
# Index(['10', '54', '45', '1.9691e+05', '0.297', '-0.538'], dtype='object')
# R-squared score: -0.3120042062493267
# Index(['8', '47', '55', '1.9691e+05', '-0.412', '0.014'], dtype='object')
# R-squared score: -0.07813401492614269
# Index(['10', '9', '25', '1.9691e+05', '0.148', '-0.025'], dtype='object')
# R-squared score: -0.1798145545113703
# Index(['8', '55', '15', '1.9691e+05', '0.474', '-0.014'], dtype='object')
# R-squared score: -0.2097271472317761
# Index(['9', '26', '15', '1.9691e+05', '-1.586', '-0.389'], dtype='object')
# R-squared score: 0.08606598225567685
# Index(['11', '5', '35', '1.9691e+05', '0.306', '1.548'], dtype='object')
# R-squared score: -0.21423485170925582
# Index(['9', '47', '55', '1.9691e+05', '0.02', '-0.339'], dtype='object')
# R-squared score: -0.15617664523211294
# Index(['9', '31', '45', '1.9691e+05', '-0.086', '0.637'], dtype='object')
# R-squared score: 0.209516185656769
# Index(['10', '54', '55', '1.9691e+05', '0.18', '-0.684'], dtype='object')
# R-squared score: -0.17296448398546005
# Index(['10', '18', '35', '1.9691e+05', '0.29', '-0.549'], dtype='object')
# R-squared score: 0.011993031950576993
# Index(['10', '54', '5', '1.9691e+05', '-0.445', '0.226'], dtype='object')
# R-squared score: -0.21673580115335334
# Index(['9', '17', '45', '1.9691e+05', '0.422', '-0.694'], dtype='object')
# R-squared score: -0.2154942668363493
# Index(['9', '38', '15', '1.9691e+05', '0.272', '-0.323'], dtype='object')
# R-squared score: -0.25427231480937906
# Index(['9', '46', '25', '1.9691e+05', '0.028', '0.304'], dtype='object')
# R-squared score: -0.5445214148193951
# Index(['10', '6', '15', '1.9691e+05', '0.173', '0.402'], dtype='object')
# R-squared score: -0.2602580085356423
# Index(['11', '1', '5', '1.9691e+05', '-0.277', '0.294'], dtype='object')
# R-squared score: -0.22025635186072323
# Index(['10', '3', '55', '1.9691e+05', '0.275', '0.15'], dtype='object')
# R-squared score: -0.685901340144802
# Index(['9', '20', '25', '1.9691e+05', '0.123', '-0.242'], dtype='object')
# R-squared score: -0.1820698969370138
# Index(['9', '3', '5', '1.9691e+05', '0.404', '0.876'], dtype='object')
# R-squared score: -0.10435634971046936
# Index(['10', '11', '55', '1.9691e+05', '5.163', '6.107'], dtype='object')
# R-squared score: -0.9692069331009205
# Index(['11', '0', '15', '1.9691e+05', '0.136', '0.381'], dtype='object')
# R-squared score: -0.23299689888815656
# Index(['9', '41', '25', '1.9691e+05', '-0.334', '0.369'], dtype='object')
# R-squared score: -0.22805314273461863
# Index(['9', '46', '45', '1.9691e+05', '0.214', '-0.648'], dtype='object')
# R-squared score: -0.1662044879383504
# Index(['8', '54', '5', '1.9691e+05', '-0.031', '0.251'], dtype='object')
# R-squared score: -0.0489210748789386
# Index(['9', '3', '15', '1.9691e+05', '-0.117', '0.006'], dtype='object')
# R-squared score: -0.20299909240658853
# Index(['9', '42', '5', '1.9691e+05', '-0.252', '0.533'], dtype='object')
# R-squared score: -0.18272131211953702
# Index(['9', '32', '35', '1.9691e+05', '-0.345', '0.366'], dtype='object')
# R-squared score: 0.28383373775705634
# Index(['11', '7', '25', '1.9691e+05', '1.903', '1.185'], dtype='object')
# R-squared score: -0.2985763922825422
# Index(['9', '42', '45', '1.9691e+05', '0.295', '-0.579'], dtype='object')
# R-squared score: -0.3545128947351548
# Index(['9', '52', '25', '1.9691e+05', '-0.07', '-0.086'], dtype='object')
# R-squared score: -0.17603987554318734
# Index(['9', '20', '45', '1.9691e+05', '-1.079', '-0.121'], dtype='object')
# R-squared score: -0.2887710037452238
# Index(['9', '37', '15', '1.9691e+05', '-0.144', '-0.121'], dtype='object')
# R-squared score: -0.24637818103165654
# Index(['10', '35', '25', '1.9691e+05', '0.043', '-0.35'], dtype='object')
# R-squared score: -0.6841725572025679
# Index(['10', '2', '25', '1.9691e+05', '-0.148', '0.26'], dtype='object')
# R-squared score: -0.16912971260382847
# Index(['8', '56', '5', '1.9691e+05', '0.379', '0.124'], dtype='object')
# R-squared score: -0.20000846006050899
# Index(['10', '43', '5', '1.9691e+05', '-0.413', '0.719'], dtype='object')
# R-squared score: -0.28553058196032977
# Index(['9', '59', '25', '1.9691e+05', '0.436', '-0.227'], dtype='object')
# R-squared score: -0.2799208715872916
# Index(['11', '3', '45', '1.9691e+05', '-0.334', '-0.373'], dtype='object')
# R-squared score: -0.23154570458767187
# Index(['9', '35', '5', '1.9691e+05', '-0.08', '-0.26'], dtype='object')
# R-squared score: -0.08641018003288714
# Index(['11', '10', '55', '1.9691e+05', '1.835', '-0.072'], dtype='object')
# R-squared score: -0.19311013989933912
# Index(['10', '37', '15', '1.9691e+05', '-0.173', '-0.133'], dtype='object')
# R-squared score: -0.2256673446388051
# Index(['10', '45', '35', '1.9691e+05', '0.04', '-0.3'], dtype='object')
# R-squared score: -0.18165641038257307
# Index(['10', '51', '35', '1.9691e+05', '0.299', '0.291'], dtype='object')
# R-squared score: -0.2626677094147589
# Index(['10', '50', '55', '1.9691e+05', '-0.263', '-0.298'], dtype='object')
# R-squared score: -0.21668302836430509
# Index(['10', '9', '15', '1.9691e+05', '0.587', '-0.63'], dtype='object')
# R-squared score: -0.1505851294473488
# Index(['10', '58', '45', '1.9691e+05', '-0.232', '-0.674'], dtype='object')
# R-squared score: -0.194457746171101
# Index(['10', '6', '45', '1.9691e+05', '0.347', '-0.428'], dtype='object')
# R-squared score: -0.17698562010509722
# Index(['9', '14', '5', '1.9691e+05', '0.282', '0.308'], dtype='object')
# R-squared score: -0.2506039209843258
# Index(['9', '43', '15', '1.9691e+05', '-0.019', '0.104'], dtype='object')
# R-squared score: -0.2843237795723861
# Index(['10', '25', '45', '1.9691e+05', '-0.166', '0.567'], dtype='object')
# R-squared score: -0.20406254282659853
# Index(['9', '8', '35', '1.9691e+05', '-0.598', '-0.543'], dtype='object')
# R-squared score: 0.022805573650068633
# Index(['8', '54', '45', '1.9691e+05', '0.007', '-2.604'], dtype='object')
# R-squared score: -0.11020894129994296
# Index(['9', '6', '55', '1.9691e+05', '0.285', '0.66'], dtype='object')
# R-squared score: -0.3222029702781888
# Index(['9', '1', '55', '1.9691e+05', '0.418', '-0.349'], dtype='object')
# R-squared score: -0.03512473510900227
# Index(['9', '38', '55', '1.9691e+05', '0.161', '0.917'], dtype='object')
# R-squared score: -0.19388524534182938
# Index(['9', '7', '55', '1.9691e+05', '0.325', '0.093'], dtype='object')
# R-squared score: -0.12392215869875134
# Index(['10', '31', '55', '1.9691e+05', '0.288', '-0.001'], dtype='object')
# R-squared score: -0.2678677244999661
# Index(['9', '51', '15', '1.9691e+05', '-0.269', '-0.049'], dtype='object')
# R-squared score: -0.26555861503844724
# Index(['9', '28', '25', '1.9691e+05', '0.269', '-0.15'], dtype='object')
# R-squared score: -0.24491727270063812
# Index(['8', '58', '5', '1.9691e+05', '0.111', '-0.114'], dtype='object')
# R-squared score: -0.0688893680366911
# Index(['8', '55', '5', '1.9691e+05', '0.439', '-0.505'], dtype='object')
# R-squared score: -0.12905002757180561
# Index(['11', '8', '55', '1.9691e+05', '-3.292', '5.439'], dtype='object')
# R-squared score: -0.23373829303624905
# Index(['10', '58', '15', '1.9691e+05', '-0.125', '-0.546'], dtype='object')
# R-squared score: -0.3189676131437684
# Index(['10', '5', '15', '1.9691e+05', '-0.135', '0.748'], dtype='object')
# R-squared score: -0.040715801901255455
# Index(['10', '14', '5', '1.9691e+05', '0.424', '0.235'], dtype='object')
# R-squared score: -0.011107543822938881
# Index(['8', '55', '25', '1.9691e+05', '-0.271', '-0.244'], dtype='object')
# R-squared score: -0.17332128179496098
# Index(['10', '25', '25.1', '1.9691e+05', '0.074', '-0.262'], dtype='object')
# R-squared score: -0.26220653724863174
# Index(['9', '34', '45', '1.9691e+05', '0.545', '0.196'], dtype='object')
# R-squared score: -0.20831812621762058
# Index(['10', '36', '45', '1.9691e+05', '0.434', '-0.862'], dtype='object')
# R-squared score: -0.2615975718012644
# Index(['10', '16', '15', '1.9691e+05', '0.01', '0.417'], dtype='object')
# R-squared score: -0.28445029598470817
# Index(['9', '49', '45', '1.9691e+05', '0.39', '0.03'], dtype='object')
# R-squared score: -0.22354296803689766
# Index(['10', '45', '45.1', '1.9691e+05', '-0.12', '0.121'], dtype='object')
# R-squared score: -0.3355776594146358
# Index(['9', '32', '5', '1.9691e+05', '0.174', '-0.153'], dtype='object')
# R-squared score: -0.24384183166512097
# Index(['8', '48', '35', '1.9691e+05', '-0.482', '0.623'], dtype='object')
# R-squared score: -0.1771544279862205
# Index(['10', '0', '15', '1.9691e+05', '0.538', '-0.176'], dtype='object')
# R-squared score: -0.19560142088325883
# Index(['10', '11', '45', '1.9691e+05', '0.391', '-1.666'], dtype='object')
# R-squared score: -0.3169193843047071
# Index(['10', '2', '55', '1.9691e+05', '-0.384', '0.3'], dtype='object')
# R-squared score: -0.22886326610888363
# Index(['9', '40', '55', '1.9691e+05', '0.377', '0.199'], dtype='object')
# R-squared score: -0.3200434967072254
# Index(['9', '40', '45', '1.9691e+05', '-0.693', '0.439'], dtype='object')
# R-squared score: -0.2991713499970343
# Index(['9', '47', '35', '1.9691e+05', '-0.168', '-0.312'], dtype='object')
# R-squared score: -0.23550895291998364
# Index(['11', '4', '35', '1.9691e+05', '0.274', '0.66'], dtype='object')
# R-squared score: -0.1449098098296817
# Index(['10', '7', '15', '1.9691e+05', '-0.222', '-0.15'], dtype='object')
# R-squared score: -0.11698360263727858
# Index(['11', '4', '45', '1.9691e+05', '-0.039', '0.366'], dtype='object')
# R-squared score: -0.13931421048724824

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

def read_csv_files(directories):
    """
    Read all of the CSV files in the specified directories.

    Args:
        directories: A list of directories, each containing CSV files.

    Returns:
        A dictionary of DataFrames, where keys are the directories and values are the corresponding DataFrames.
    """

    dataframes = {}
    for directory in directories:
        csv_files = os.listdir(directory)
        dfs = []
        for csv_file in csv_files:
            dataframe = pd.read_csv(os.path.join(directory, csv_file))
            dfs.append(dataframe)
        dataframes[directory] = dfs

    return dataframes
def plot_rul_prediction(data):
    """
    Plot the RUL predictions against the true RUL values over cycles.

    Args:
        data: DataFrame containing the predicted and true RUL values.
    """

    plt.figure(figsize=(10, 6))

    # Create a new column 'Cycle' representing the cycle number for each row
    data['Cycle'] = range(1, len(data) + 1)

    # Plot True RUL and Predicted RUL over cycles
    plt.plot(data['Cycle'], data['True RUL'], label='True RUL', marker='*')
    plt.plot(data['Cycle'], data['Predicted RUL'], label='Predicted RUL', marker='.')

    plt.xlabel('Cycle')
    plt.ylabel('RUL')
    plt.title('True RUL vs. Predicted RUL over Cycles')
    plt.legend()
    plt.grid(True)
    plt.show()


def train_main():
    # List of directories containing the CSV files for each bearing set
    directories = [
        "/content/drive/MyDrive/fsm/Test_set/Bearing1_3",
        "/content/drive/MyDrive/fsm/Test_set/Bearing1_4",
        "/content/drive/MyDrive/fsm/Test_set/Bearing1_5",
        "/content/drive/MyDrive/fsm/Test_set/Bearing1_6",
        "/content/drive/MyDrive/fsm/Test_set/Bearing1_7"
    ]
    dataframes_dict = read_csv_files(directories)

    # Loop over the CSV files and train a model on each one
    for directory, dataframes in dataframes_dict.items():
        for i, dataframe in enumerate(dataframes):
            # Process each DataFrame, such as preprocessing, model training, etc.
            # Use 'directory' variable to keep track of the current bearing set.
            pass

        # Print column names to find the correct name of the target variable (RUL) column
        print(data.columns)

        # Assume the target variable is in the last column (index -1)
        target_column_index = -1
        X = data.drop(data.columns[target_column_index], axis=1)
        y = data[data.columns[target_column_index]]

        # Initialize the imputer with the desired strategy (e.g., mean, median, most frequent)
        imputer = SimpleImputer(strategy='mean')

        # Fit the imputer on the data and transform
        X_imputed = imputer.fit_transform(X)

        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size=0.2, random_state=42)

        # Train the RUL prediction model
        rul_model = train_rul_model(X_train, y_train)

        # Evaluate the model's performance on the test set (e.g., using mean squared error)
        score = rul_model.score(X_test, y_test)
        print("R-squared score:", score)

        # Add the predicted RUL values to the DataFrame
        data['Predicted RUL'] = rul_model.predict(X_imputed)
        data['True RUL'] = y

    return data

if __name__ == "__main__":
    data = train_main()
    plot_rul_prediction(data)
# Out:
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')
# R-squared score: 0.9999983122994599

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(data.columns)
# Out:
# Index(['10', '19', '11', '6.1879e+05', '0.172', '-0.033', 'Predicted RUL',
#        'True RUL', 'Cycle'],
#       dtype='object')

# %%
print(data.head(25))
# Out:
#     10  19  11  6.1879e+05  0.172  -0.033  Predicted RUL  True RUL  Cycle
# 0   10  19  11    618830.0  0.133  -0.092           1.99         1      1
# 1   10  19  11    618870.0 -0.242  -0.178           2.24         2      2
# 2   10  19  11    618910.0 -0.040  -0.282           2.88         3      3
# 3   10  19  11    618940.0 -0.314   0.625           3.91         4      4
# 4   10  19  11    618980.0 -0.015  -0.107           5.02         5      5
# 5   10  19  11    619020.0  0.323  -0.159           6.00         6      6
# 6   10  19  11    619060.0 -0.003   0.026           6.84         7      7
# 7   10  19  11    619100.0  0.154  -0.039           7.80         8      8
# 8   10  19  11    619140.0 -0.014  -0.166           8.65         9      9
# 9   10  19  11    619180.0  0.227  -0.337           9.82        10     10
# 10  10  19  11    619220.0  0.077   0.418          11.12        11     11
# 11  10  19  11    619260.0  0.077  -0.149          11.94        12     12
# 12  10  19  11    619300.0 -0.179  -0.163          12.84        13     13
# 13  10  19  11    619340.0  0.149  -0.047          14.18        14     14
# 14  10  19  11    619370.0 -0.013   0.227          14.88        15     15
# 15  10  19  11    619410.0  0.093   0.361          15.65        16     16
# 16  10  19  11    619450.0  0.041  -0.674          17.12        17     17
# 17  10  19  11    619490.0 -0.079   0.223          17.88        18     18
# 18  10  19  11    619530.0 -0.047   0.153          18.96        19     19
# 19  10  19  11    619570.0  0.108  -0.100          19.73        20     20
# 20  10  19  11    619610.0  0.036  -0.155          21.04        21     21
# 21  10  19  11    619650.0  0.062   0.156          21.98        22     22
# 22  10  19  11    619690.0  0.007  -0.048          22.64        23     23
# 23  10  19  11    619730.0 -0.004  -0.638          23.84        24     24
# 24  10  19  11    619760.0  0.261   0.629          24.61        25     25
